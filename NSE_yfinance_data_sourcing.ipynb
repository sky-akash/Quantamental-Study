# %%
# 
# Script to Download NSE Listed Companies Data and Store in SQLite Database from yfinance
#

# %%
# 1. Python Library Dependencies
# !pip install yfinance sqlalchemy pandas --quiet

import sys
import pandas as pd
import yfinance as yf
import sqlalchemy
import time
import os
import numpy as np


# --- CONFIGURATION ---
os.makedirs("data", exist_ok=True)                  # Ensuring existence of data directory
EXCEL_FILE = 'data/NSE_listed_companies_Filtered.xlsx'       # csv with names of companies
DB_NAME = 'data/NSE_Companies_filtered.db'

# 1. Configuration Parameters
START_DATE = '2004-09-01'            # start date
VOLATILITY_WINDOW = 30               # 30-Day Rolling Volatility

# 2. Connect to New Database
engine = sqlalchemy.create_engine(f'sqlite:///{DB_NAME}')
print(f"Created new database: {DB_NAME}")

# ==========================================
# PART 1: RESTORING SECTOR INFO
# ==========================================
print("\nPART 1: Creating 'stock_info' table from CSV...")

if not os.path.exists(EXCEL_FILE):
    print(f"CRITICAL: '{EXCEL_FILE}' not found.")
    sys.exit(1)

try:
    df = pd.read_excel(EXCEL_FILE)

    # Selecting relevant columns
    # Adjusting column names
    master_df = df[['TickerSymbol', 'Name', 'Sector']].copy()

    # Standardizing Column Names for SQL_smallcaps and using _
    master_df.columns = ['symbol', 'company_name', 'industry']

    # Adding .NS extension to symbol for yfinance
    master_df['symbol'] = master_df['symbol'].apply(lambda x: f"{x}.NS")

    # Saving to DB
    master_df.to_sql('stock_info', engine, if_exists='replace', index=False)

    # Retrieving list of tickers
    tickers = master_df['symbol'].tolist()
    print(f"Restored {len(tickers)} stocks into 'stock_info'.")

except Exception as e:
    print(f"Error reading CSV: {e}")
    sys.exit(1)

# ==========================================
# PART 2: DOWNLOADING 20 YEARS HISTORY
# ==========================================
print(f"\nPART 2: Downloading Daily Data (Start: {START_DATE})...")

success_count = 0
batch_size = 100                       # Downloading in Batches

# Looping through tickers
for i, ticker in enumerate(tickers):
    try:
        # A. Downloading Data
                                                                                # auto_adjust=True to handle Splits/Dividends
        df = yf.download(ticker, start=START_DATE, progress=False, interval = "1d",
                         auto_adjust=True, threads=True)

        if not df.empty:
            # Flatten columns
            if isinstance(df.columns, pd.MultiIndex):
                df.columns = [col[0] for col in df.columns]

            # B. Cleaning the Data
            df.reset_index(inplace=True)
            df.rename(columns={'Date': 'date', 'Open': 'open', 'High': 'high',
                               'Low': 'low', 'Close': 'close', 'Volume': 'volume'}, inplace=True)

            # Ensuring lowercasing of columns
            df.columns = [c.lower() for c in df.columns]

            # C. Feature Engineering (Volatility & Returns)
            # 1. Log Returns
            df['log_return'] = np.log(df['close'] / df['close'].shift(1))

            # 2. 5-30-60_Day Volatility
            df['volatility_5d'] = df['log_return'].rolling(window=5).std()                      # 5 day volatility
            df['volatility_30d'] = df['log_return'].rolling(window=VOLATILITY_WINDOW).std()     # 30 day volatility
            df['volatility_60d'] = df['log_return'].rolling(window=2*VOLATILITY_WINDOW).std()   # 60 day volatility

            # Dropping NaN rows generated by rolling window
            df.dropna(inplace=True)

            # D. Saving to Database
            # Table name = Ticker                                               (will save like "RELIANCE.NS"... so need to handle ticker names wtih EIKON separately)
            df.to_sql(ticker, engine, if_exists='replace', index=False)

            success_count += 1

        # Progress Update
        if i % 100 == 0:
            print(f"Processed {i}/{len(tickers)}: {ticker}")

    except Exception as e:
        print(f"Error {ticker}: {e}")

print(f"\n Download Complete ! Database created with {success_count} stocks.")
# Out:
# Created new database: data/NSE_Companies_filtered.db
#
# PART 1: Creating 'stock_info' table from CSV...
# Restored 2159 stocks into 'stock_info'.
#
# PART 2: Downloading Daily Data (Start: 2004-09-01)...
# Processed 0/2159: BEL.NS
# Processed 100/2159: SPLPETRO.NS
# Processed 200/2159: JYOTISTRUC.NS
# Processed 300/2159: KSB.NS
# Processed 400/2159: KMSUGAR.NS
# Processed 500/2159: WSTCSTPAPR.NS
# Processed 600/2159: SALSTEEL.NS
# 1 Failed download:
# ['TULSYAN.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2004-09-01 -> 2025-11-28)')
# Processed 700/2159: KSERASERA.NS
# Processed 800/2159: IPCALAB.NS
# c:\Users\Akash Mittal\Documents\GitHub\AI Trade Challenge\my-ollama-project\.venv311\Lib\site-packages\pandas\core\arraylike.py:399: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Processed 900/2159: BSOFT.NS
# Failed to get ticker 'WESTLIFE.NS' reason: Failed to perform, curl: (28) Operation timed out after 10005 milliseconds with 0 bytes received. See https://curl.se/libcurl/c/libcurl-errors.html first for more details.
#
# 1 Failed download:
# ['WESTLIFE.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522229.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513252.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['515043.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500178.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523248.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523638.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['504908.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505163.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505681.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505712.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505978.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507998.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500168.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['509162.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522195.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500267.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513687.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Processed 1000/2159: 513687.NS
# 1 Failed download:
# ['500240.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530711.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530369.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517286.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500389.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526471.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507155.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507435.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['508136.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['508670.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519532.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530305.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526945.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507690.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522294.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['512301.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531671.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519097.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507753.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524440.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524522.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524534.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524576.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524582.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524590.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524592.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524594.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524634.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526409.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526415.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526492.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513353.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514165.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514223.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519014.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523712.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523782.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524013.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524038.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524080.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500123.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524174.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500012.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524218.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500449.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524288.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524336.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524408.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526231.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526335.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['503776.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['504176.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505710.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['504092.NS']: YFPricesMissingError('possibly delisted; no price data found  (1d 2004-09-01 -> 2025-11-29)')
#
# 1 Failed download:
# ['531862.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['506373.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['506532.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['506543.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['506597.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['506605.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['506687.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['506734.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['506808.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['506854.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500298.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['506945.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507486.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500358.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507759.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507813.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507817.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['509486.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532468.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531541.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524687.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531253.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530845.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524818.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514448.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531157.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526821.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530627.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531287.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530027.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531257.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530611.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526159.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524717.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524434.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514183.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['509470.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532425.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532067.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524808.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530133.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530429.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513642.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530825.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531111.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['506520.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Processed 1100/2159: 506520.NS
# 1 Failed download:
# ['524748.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531280.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524046.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531397.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530991.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530433.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526901.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530883.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['509895.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524204.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500306.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500270.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['506858.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531779.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531454.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524488.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524156.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524504.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526315.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['511411.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514171.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['515085.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['516003.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['518011.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['502015.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500322.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['502271.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['502281.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523483.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523594.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523650.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523732.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526193.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507828.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['509423.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['509597.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513528.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['520121.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522209.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522231.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530543.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526823.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526654.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526705.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532323.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531297.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531273.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530977.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531129.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517356.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526865.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524642.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514442.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531416.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532016.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['512329.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['503657.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530973.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526225.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526839.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531540.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['509845.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513699.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526941.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531049.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526025.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['512215.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507968.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514332.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514336.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531797.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531784.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531338.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531444.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526187.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['518053.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517063.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531840.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['508918.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['512277.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['506530.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523222.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530407.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526237.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523209.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513452.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517336.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526588.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['515008.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517096.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517201.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517246.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517258.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517264.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523558.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526117.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['504132.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['504240.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['504258.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['508941.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Processed 1200/2159: 508941.NS
# 1 Failed download:
# ['517467.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531201.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517514.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['504084.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517564.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517370.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531460.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531306.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531889.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517423.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531888.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531472.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532676.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531989.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526494.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523021.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500421.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523652.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523874.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526137.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526169.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['506979.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['516078.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517437.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526853.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530315.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530063.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['504840.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526717.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530145.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['515147.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526703.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514440.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514428.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526604.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523315.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530111.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530197.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523840.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526554.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526841.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530931.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531413.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526001.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523323.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['NAN.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523696.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523489.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526783.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530897.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531043.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524520.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524564.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524614.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526113.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507474.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500319.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507498.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['515059.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519003.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519152.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519174.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519285.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519287.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523309.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523475.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523672.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507300.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507598.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507621.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507663.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['508494.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519216.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519234.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519238.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519279.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519413.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519457.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519475.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519477.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519483.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519500.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500166.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524480.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526899.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526739.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532038.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532005.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532645.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519359.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530959.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530119.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519612.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530217.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507515.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530053.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522289.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519191.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530741.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526125.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Processed 1300/2159: 526125.NS
# 1 Failed download:
# ['519606.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519506.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519230.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530461.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519242.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519031.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519566.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530953.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530735.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530291.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519064.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531156.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523164.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532183.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519295.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531930.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531923.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531980.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519421.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['508571.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526081.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519397.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526586.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514264.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526143.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505299.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505729.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514360.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['508486.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['509196.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['511131.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531869.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523467.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530621.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526751.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505725.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522237.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531928.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505840.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526616.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530589.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526043.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522245.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522251.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513472.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517360.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500246.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517397.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['520075.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522004.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522005.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522017.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522027.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522036.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522101.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522105.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522134.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500147.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523160.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523660.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523832.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526173.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['504000.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['504076.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['504959.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505250.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505302.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500450.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505358.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505650.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505690.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505737.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505750.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505797.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500360.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505807.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505890.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507944.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513337.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513575.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500248.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517417.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500028.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['502865.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['504786.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['501391.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513149.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526731.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513709.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517546.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531215.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505232.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522267.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505212.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526614.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523850.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531780.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526711.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531594.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522183.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Processed 1400/2159: 522183.NS
# 1 Failed download:
# ['530267.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522152.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505320.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['522171.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['508860.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505693.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531661.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531727.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505893.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500068.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505872.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532397.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526490.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514302.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['516020.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500357.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['516032.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['516038.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['502587.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['502589.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500223.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['503349.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514414.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500159.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['516062.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['521080.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500264.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['512233.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['516108.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530201.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531436.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500388.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532503.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['516096.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530169.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514312.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530331.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['512618.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['516106.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['521226.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530255.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531503.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526435.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530035.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526638.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514236.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530037.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['512297.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524458.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531744.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531859.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531437.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507872.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517320.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['520123.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532402.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['511736.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531842.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526931.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530177.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532435.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531758.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['504810.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523062.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531158.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530755.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505336.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['502893.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['508867.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523116.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519604.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['511688.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['511714.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['501370.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531381.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513005.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513043.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513117.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513119.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513173.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500058.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513295.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513303.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513309.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513361.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513369.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513397.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513403.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513456.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ...
#
# 1 Failed download:
# ['524604.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526075.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532131.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531762.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['511509.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531686.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530233.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['506365.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531210.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524790.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524314.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['513430.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531219.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530617.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Processed 2000/2159: 530617.NS
# 1 Failed download:
# ['530125.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524703.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531637.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531173.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531015.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519574.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530665.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524632.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500672.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514197.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519307.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['521149.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['502445.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['503229.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500307.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505216.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500142.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['511441.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523007.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531574.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526727.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['512493.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531518.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531337.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507836.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['521228.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526519.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526813.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531228.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530821.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532467.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531968.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523289.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['504746.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507833.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['514378.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['521105.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532444.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531041.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531583.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523606.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531626.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523888.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526971.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526905.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531962.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['511601.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524580.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['524622.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526433.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526445.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517044.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517119.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523387.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523722.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['511525.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517429.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['521167.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531161.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532403.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532404.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530643.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['512093.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523411.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532344.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['538922.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['511658.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532072.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['512379.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532329.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517477.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530951.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531738.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526709.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531396.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['512405.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532320.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531525.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530595.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517494.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531268.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531489.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532373.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['504351.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531621.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532379.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532139.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532100.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531083.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530175.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523151.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['505504.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531529.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532315.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531658.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['512149.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532336.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532359.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532303.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['511644.NS']: YFTzMissingError('possibly delisted; no timezone found')
# Processed 2100/2159: 511644.NS
# 1 Failed download:
# ['531769.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['511447.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517415.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531533.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526443.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531126.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531960.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532340.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['519463.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531917.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500346.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531812.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['511116.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['517236.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523277.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['509073.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532350.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532380.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526775.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531898.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532123.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['503685.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['511664.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531996.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532378.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531775.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['511401.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['511246.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526477.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['523710.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500285.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500016.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507960.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['509438.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532485.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532145.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526640.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507981.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526761.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['509960.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532275.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526755.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532355.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['532334.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['509546.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['512634.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526373.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531033.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['500213.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['508664.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['530065.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526795.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526687.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['507966.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526721.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526628.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['526959.NS']: YFTzMissingError('possibly delisted; no timezone found')
#
# 1 Failed download:
# ['531234.NS']: YFTzMissingError('possibly delisted; no timezone found')
#  Download Complete ! Database created with 982 stocks.

# %%
print("Current Working Directory:", os.getcwd())
# Out:
# Current Working Directory: c:\Users\Akash Mittal\Documents\GitHub\Quantamental Study\code
