# %% [markdown]
# ----
# <img src="../../files/lseg.svg" class="rft-examples-logo" width="20%" style="vertical-align: top;">
#
# # Data Library for Python
#
# ----

# %% [markdown]
# ## Access layer - News
# This notebook demonstrates how to retrieve News story and headlines data using the get_story() and get_headlines() functions.

# %% [markdown]
# #### About the get_headlines function
# The get_headlines() function allows you to retrieve news headlines via a single function call.
#
# ***get_headlines()*** parameters:
# - ***query***: The user search query.
#     - Type: String
#     - Optionnal: No
# - ***count***: Count to limit number of headlines. Min value is 0. Default: 10
#     - Type: int
#     - Optionnal: Yes
# - ***start***: Beginning of date range. String format is: '%Y-%m-%dT%H:%M:%S'. e.g. '2016-01-20T15:04:05'.
#     - Type: str or timedelta, optional
#     - Optionnal: Yes
# - ***end***: End of date range. String format is: '%Y-%m-%dT%H:%M:%S'. e.g. '2016-01-20T15:04:05'.
#     - Type: str or timedelta, optional
#     - Optionnal: Yes
# - ***order_by***: Value from SortOrder enum. Default: SortOrder.new_to_old
#     - Type: SortOrder
#     - Optionnal: Yes
#
# **get_headlines()** pd.DataFrame. Headlines dataframe.
#
# #### About the get_story function
# The get_story() function allows you to retrieve news story data.
#
# ***get_story()*** parameters:
# - ***story_id***: News Story ID
#     - Type: String
#     - Optionnal: No
# - ***format***: Specifies the type of response. If parameter Format.TEXT return text string, otherwise returns HTML response
#     - Type: String or Format enum
#     - Optionnal: Yes
#
# **get_story()** returns a story html or text response

# %% [markdown]
# #### Learn more
#
# To learn more about the LSEG Data Library for Python please join the LSEG Developer Community. By [registering](https://developers.lseg.com/iam/register) and [logging](https://developers.lseg.com/content/devportal/en_us/initCookie.html) into the LSEG Developer Community portal you will have free access to a number of learning materials like
#  [Quick Start guides](https://developers.lseg.com/en/api-catalog/lseg-data-platform/lseg-data-library-for-python/quick-start),
#  [Tutorials](https://developers.lseg.com/en/api-catalog/lseg-data-platform/lseg-data-library-for-python/tutorials),
#  [Documentation](https://developers.lseg.com/en/api-catalog/lseg-data-platform/lseg-data-library-for-python/documentation)
#  and much more.
#
# #### Getting Help and Support
#
# If you have any questions regarding using the API, please post them on
# the [Data Library Q&A Forum](https://community.developers.refinitiv.com/smart-spaces/521/index.html).
# The LSEG Developer Community will be happy to help.
#
# ----

# %% [markdown]
# ## Some Imports to start with

# %%
import lseg.data as ld
from datetime import timedelta
from IPython.display import HTML

# %% [markdown]
# ## Open the data session
#
# The open_session() function creates and open sessions based on the information contained in the lseg-data.config.json configuration file. Please edit this file to set the session type and other parameters required for the session you want to open.

# %%
ld.open_session()
# Out:
# <lseg.data.session.Definition object at 0x112b98d90 {name='workspace'}>

# %% [markdown]
# ## Retrieve data

# %% [markdown]
# ### Get headlines

# %%
ld.news.get_headlines("LSEG.L", start="20.08.2024", end=timedelta(days=-4), count=10)
# Out:
#                                                                   headline  \
# versionCreated
# 2024-09-02 07:08:52.846  Investors look to see if London Stock Exchange...
# 2024-09-02 06:54:15.379  Monthly: London Stock Exchange Group (LSEG: GB...
# 2024-09-02 06:38:58.950  Weekly: London Stock Exchange Group (LSEG: GBX...
# 2024-09-02 03:00:03.556  Metalpha Adopts New Bitcoin Mining Index by An...
# 2024-09-02 03:00:00.000  Metalpha Adopts New Bitcoin Mining Index by An...
# 2024-09-02 03:00:00.000  Press Release: Metalpha Adopts New Bitcoin Min...
# 2024-09-01 23:00:00.000  DJ London Stock Exchange CEO David Schwimmer: ...
# 2024-08-31 13:44:38.992  PPC, inclusă în seria de indici FTSE4Good a Lo...
# 2024-08-31 12:07:01.534  Dominic Blakemore Director of London Stock Exc...
# 2024-08-31 11:47:18.229  David Schwimmer, London Stock Exchange Group C...
#
#                                                               storyId  \
# versionCreated
# 2024-09-02 07:08:52.846     urn:newsml:newsroom:20240902:nNRAtpr8q0:0
# 2024-09-02 06:54:15.379     urn:newsml:newsroom:20240902:nNRAtpqwoo:0
# 2024-09-02 06:38:58.950     urn:newsml:newsroom:20240902:nNRAtpqfk7:0
# 2024-09-02 03:00:03.556  urn:newsml:reuters.com:20240902:nPnbPVWZRa:1
# 2024-09-02 03:00:00.000  urn:newsml:reuters.com:20240901:nDjcb83T9G:1
# 2024-09-02 03:00:00.000  urn:newsml:reuters.com:20240901:nDjc2qc9l3:2
# 2024-09-01 23:00:00.000  urn:newsml:reuters.com:20240901:nDjc3cS1df:2
# 2024-08-31 13:44:38.992        urn:link:webnews:20240831:nNRAtpeurr:0
# 2024-08-31 12:07:01.534     urn:newsml:newsroom:20240831:nNRAtpe5my:0
# 2024-08-31 11:47:18.229     urn:newsml:newsroom:20240831:nNRAtpdz99:0
#
#                         sourceCode
# versionCreated
# 2024-09-02 07:08:52.846  NS:GLOSTO
# 2024-09-02 06:54:15.379  NS:NEWMAR
# 2024-09-02 06:38:58.950  NS:NEWMAR
# 2024-09-02 03:00:03.556     NS:PRN
# 2024-09-02 03:00:00.000    NS:DJCP
# 2024-09-02 03:00:00.000    NS:DJCP
# 2024-09-01 23:00:00.000    NS:DJCP
# 2024-08-31 13:44:38.992  NS:GANINF
# 2024-08-31 12:07:01.534  NS:NEWPEO
# 2024-08-31 11:47:18.229  NS:NEWPEO

# %% [markdown]
# ### Get story

# %%
story = ld.news.get_story("urn:newsml:newsroom:20240819:nNRAtl9658:0", format=ld.news.Format.HTML)
HTML(story)
# Out:
# <div lang="en"><div class="tr-npp-lead"><p>GLOBAL ROUND UP</p><p>ADRS AND DEPOSITORY RECEIPTS</p></div><div class="tr-npp-body"><p>Ahead of this morning's market opening, London Stock Exchange ADR has shown some strength in recent days. London Stock Exchange (OT:LNSTY), the International Depository Receipt (IDR) market's 2nd largest Diversified financial services company by market cap, increased 0.5% during its previous trading session to close at $32.69.</p><p>Institutional ownership updated after last SEC Filing Q1/2024 reported on May 18</p><p>Institutional Ownership as at Jun 30, 2024</p><p>Reported holdings of institutions end of quarter</p><p>As at March 31, 2024 institutions had decreased their holdings to 0.01% of issued capital, down from 0.1% nine months ago.</p><div class="story-table-container"><table class="story-basic-table"><tbody><tr><td>Quarter - ended</td><td>Mar 31</td><td>Dec 31, 2023</td><td>Sep 30, 2023</td><td>Jun 30, 2023</td> </tr><tr><td>% of issued capital</td><td>0.01</td><td>0.1</td><td>0.1</td><td>0.1</td> </tr> </tbody> </table></div><p>Top 5 Institutional Ownership of London Stock Exchange as at March 31, 2024</p><p>As at March 31, 2024, 11 Institutions (Funds) held investments in ADRs of London Stock Exchange. Institutions decreased their holdings to 0.01% of issued capital, down from 0.1% as at Dec 31. The largest ADRholder was Azimuth Capital Investment Management LLC with 0.01% of London Stock Exchange. The second largest ADRholder was Ramirez Asset Management, Inc..</p><p>*Note: Minimum Core ADRholding is computed on the basis of SEC filings over the last 12 quarters (3 years). A higher % of ADRholding above the minimum core holding may be indicative of a potential positioning by an active institution to overweight.</p><p>London Stock Exchange Top 3 Index Funds (in desc order of ADRs) hold 0.01% [second last column shows % above minimum core ADRholding; last column shows percentile rank by AUM (Assets Under Management) among 7098 Funds]. Please download the spreadsheet to view full list of 8 Index Funds holding 0.01% of London Stock Exchange as at March 31, 2024.</p><div class="story-table-container"><table class="story-basic-table"><tbody><tr><td>Fund</td><td>ADRs</td><td>% of Total</td><td>Value $</td><td>% above Core*</td><td>Percentile rank</td> </tr><tr><td>Azimuth Capital Investment Management LLC (0001942364)</td><td>130,005</td><td>0.01</td><td>3.9 M</td><td>5</td><td>84</td> </tr><tr><td>Ramirez Asset Management, Inc. (0001992110)</td><td>80,111</td><td>0.004</td><td>2.4 M</td><td>-</td><td>58</td> </tr><tr><td>Madison Asset Management, LLC (0001299351)</td><td>76,878</td><td>0.004</td><td>2.3 M</td><td>-</td><td>93</td> </tr><tr><td>% Held by Top 3 Institutional ADRholders</td><td>286,994</td><td>0.01</td><td>8.7 M</td><td>-</td><td>-</td> </tr> </tbody> </table></div><p>London Stock Exchange Top 2 Active Funds (in desc order of ADRs) hold 0.001% [second last column shows % above minimum core ADRholding; last column shows percentile rank by AUM (Assets Under Management) among 7098 Funds]. Please download the spreadsheet to view full list of 4 Active Funds holding 0.001% of London Stock Exchange as at March 31, 2024.</p><div class="story-table-container"><table class="story-basic-table"><tbody><tr><td>Fund</td><td>ADRs</td><td>% of Total</td><td>Value $</td><td>% above Core*</td><td>Percentile rank</td> </tr><tr><td>Rhumbline Advisers (0001115418)</td><td>16,120</td><td>0.001</td><td>486,234</td><td>66</td><td>99</td> </tr><tr><td>GAMMA Investing LLC (0002010235)</td><td>2,167</td><td>-</td><td>65,364</td><td>22</td><td>57</td> </tr><tr><td>% Held by Top 2 Institutional ADRholders</td><td>18,287</td><td>0.001</td><td>551,598</td><td>-</td><td>-</td> </tr> </tbody> </table></div><p>Institutional ownership of LNSTY at Mar 31: Rhumbline Advisers top increase of 56%</p><p>As at March 31, 2024, 3 institutions or 25.0% of LNSTY's institutional ADRholders had increased their holding of AD ...

# %%
text = ld.news.get_story("urn:newsml:newsroom:20240819:nNRAtl9658:0", format=ld.news.Format.TEXT)
print(text)
# Out:
# Can London Stock Exchange continue its gains?GLOBAL ROUND UP
#
# ADRS AND DEPOSITORY RECEIPTS
#
# Ahead of this morning's market opening, London Stock Exchange ADR has shown some strength in recent days. London Stock Exchange (OT:LNSTY), the International Depository Receipt (IDR) market's 2nd largest Diversified financial services company by market cap, increased 0.5% during its previous trading session to close at $32.69.
#
# Institutional ownership updated after last SEC Filing Q1/2024 reported on May 18
#
# Institutional Ownership as at Jun 30, 2024
#
# Reported holdings of institutions end of quarter
#
# As at March 31, 2024 institutions had decreased their holdings to 0.01% of issued capital, down from 0.1% nine months ago.
#
# Quarter - ended       Mar 31   Dec 31, 2023   Sep 30, 2023   Jun 30, 2023
# % of issued capital   0.01     0.1            0.1            0.1
#
# Top 5 Institutional Ownership of London Stock Exchange as at March 31, 2024
#
# As at March 31, 2024, 11 Institutions (Funds) held investments in ADRs of London Stock Exchange. Institutions decreased their holdings to 0.01% of issued capital, down from 0.1% as at Dec 31. The largest ADRholder was Azimuth Capital Investment Management LLC with 0.01% of London Stock Exchange. The second largest ADRholder was Ramirez Asset Management, Inc..
#
# *Note: Minimum Core ADRholding is computed on the basis of SEC filings over the last 12 quarters (3 years). A higher % of ADRholding above the minimum core holding may be indicative of a potential positioning by an active institution to overweight.
#
# London Stock Exchange Top 3 Index Funds (in desc order of ADRs) hold 0.01% [second last column shows % above minimum core ADRholding; last column shows percentile rank by AUM (Assets Under Management) among 7098 Funds]. Please download the spreadsheet to view full list of 8 Index Funds holding 0.01% of London Stock Exchange as at March 31, 2024.
#
# Fund                                                     ADRs      % of Total   Value $   % above Core*   Percentile rank
# Azimuth Capital Investment Management LLC (0001942364)   130,005   0.01         3.9 M     5               84
# Ramirez Asset Management, Inc. (0001992110)              80,111    0.004        2.4 M     -               58
# Madison Asset Management, LLC (0001299351)               76,878    0.004        2.3 M     -               93
# % Held by Top 3 Institutional ADRholders                 286,994   0.01         8.7 M     -               -
#
# London Stock Exchange Top 2 Active Funds (in desc order of ADRs) hold 0.001% [second last column shows % above minimum core ADRholding; last column shows percentile rank by AUM (Assets Under Management) among 7098 Funds]. Please download the spreadsheet to view full list of 4 Active Funds holding 0.001% of London Stock Exchange as at March 31, 2024.
#
# Fund                                       ADRs     % of Total   Value $   % above Core*   Percentile rank
# Rhumbline Advisers (0001115418)            16,120   0.001        486,234   66              99
# GAMMA Investing LLC (0002010235)           2,167    -            65,364    22              57
# % Held by Top 2 Institutional ADRholders   18,287   0.001        551,598   -               -
#
# Institutional ownership of LNSTY at Mar 31: Rhumbline Advisers top increase of 56%
#
# As at March 31, 2024, 3 institutions or 25.0% of LNSTY's institutional ADRholders had increased their holding of ADRs in London Stock Exchange from December 31. The top increase was by Rhumbline Advisers which increased its holding by 5,819 ADRs, or 56.5% to 16,120 ADRs.
#
# Top 3 Increases [March 31, 2024 vs December 31, 2023]
#
# Value is shown in the table below at March 31 LNSTY ADR price of $30.16.
#
# Institution (CIK)                                        ADRs     Value, $   % increase
# Rhumbline Advisers (0001115418)                          5,819    170,197    56.5
# GAMMA Investing LLC (0002010235)                         390      11,407     21.9
# Azimuth Capital Investment Management LLC (0001942364)   6,210    181,634    5.0
# Total                                                    12,419   363,238    -
#
# Institutional ownership of LNSTY at March 31, 2024: Azimuth Capital Investment Management LLC top increase by worth
#
# Top 3 Increases by worth [March 31, 2024 vs December 31, 2023]
#
# Value is shown in the table below at March 31 LNSTY ADR price of $30.16.
#
# Institution (CIK)                                        ADRs     Worth Change, $
# Azimuth Capital Investment Management LLC (0001942364)   6,210    181,634
# Rhumbline Advisers (0001115418)                          5,819    170,197
# GAMMA Investing LLC (0002010235)                         390      11,407
# Total                                                    12,419   363,238
#
# Institutional ownership of LNSTY at Mar 31: Madison Asset Management top decrease of 18%
#
# 3 Institutional ADRholders decreased their holdings in Q1/2024. The top decrease was Madison Asset Management who reduced their ADRholding in London Stock Exchange by 16,405 ADRs (17.6%) from 93,283 as at December 31 to 76,878 as at March 31.
#
# Top 3 Decreases [March 31, 2024 vs December 31, 2023]
#
# Value is shown in the table below at March 31 LNSTY ADR price of $30.16.
#
# Institution (CIK)                                 ADRs     Value, $    % Decreases
# Madison Asset Management, LLC (0001299351)        16,405   (479,823)   -17.6
# Ramirez Asset Management, Inc. (0001992110)       3,216    (94,063)    -3.9
# PNC Financial Services Group, Inc. (0000713676)   28       (819)       -2.8
# Total                                             19,649   (574,705)   -
#
# Drop Outs
#
# There were no Drop Outs in Q1/2024 from the list of Institutional ADRholders as at December 31, 2023.
#
# Please view detailed Institutional Shareholders - Categorised and Complete List in DATA & ARCHIVE DOWNLOAD CENTER
#
# LONDON STOCK EXCHANGE EX-DIVIDENDS SINCE AUG 16
#
# The ADRs increased by 0.5% in the today's trading session. The company paid a dividend of 13.07c per share. Based on dividends of 49.72c per share for the trailing twelve months and the last price of $32.69 the dividend yield is 1.6%.
#
# LONDON STOCK EXCHANGE GROUP (LSEG) Stock Dashboard [traded in British Pound, GBP] End-of-Day Thu, Jun 06
#
# Last                 GBX9,426.0    Market Cap               GBP50 billion [US$64 billion]         EPS Growth (FY2023 vs FY2022)   -40.6%                Today's VI*      1.2
# P/E                  67.9          Dividend Yield % (TTM)   1.2                                   Today's Volume                  1,230,000             Currency         1.000 GBP = 1.277 USD
# EPS (FY2023)         GBX1.39       DPS (past 12 months)     GBX1.1 or 1 GBX                       Ave Daily Volume                1,002,511 shares      PV$1000 (1 yr)   GBX1,103
#                                                                                                                                                                          US$1,132
# Shares Outstanding   531,280,000   Exchange                 UNITED KINGDOM [CHI-X (UK), London]   52-Week Price Range             7,682.62 - 9,611.78
# LSEG in Indices      FTSE 100      Sector                   Financial Services [of 120 stocks]
#
# http://www.londonstockexchangegroup.comVI* Volume Index = Number of shares traded today/Average number of shares traded per day.
#
# LONDON STOCK EXCHANGE (LNSTY) ADR Dashboard End-of-Day Fri, Aug 16
#
# http://www.londonstockexchange.com
#
# Last                            $32.69          Market Cap                $69 billion
# EPS (FY2023)                    $1.39           Exchange                  INTERNATIONAL DEPOSITORY RECEIPTS [USOTC]
# Shares Outstanding              2,120,000,000   % of shares outstanding   0.01%
# Institutional Ownership         309,374         Sector                    Diversified Financial Services [of 118 stocks]
# EPS Growth (FY2023 vs FY2022)   -40.6%          Today's VI*               3.4
# Today's Volume                  679,000         PV$1000 (1 yr)            $1,260
# Ave Daily Volume                197,279 ADRs
# 52-Week Price Range             24.35 - 32.74
#
# VI* Volume Index = Number of shares traded today/Average number of shares traded per day.
#
# A year ago the London Stock Exchange adr price was $25.95. $1,000 would have bought 38.5 London Stock Exchange adrs on that day. Those 38.5 ADRs would be worth $1,260 at today's adr price of $32.69. Dividends reinvested are worth $22. PV$1000= $1,281.
#
# *Total ADRs Held by Institutions 309,374; equivalent to 77,344 London Stock Exchange shares on issue. This represents 0.01% of total shares on issue.
#
# Past quarter momentum up: London Stock Exchange surges 11%
#
# Past month to   High    Low     VWAP    Volume Index *
# 16 Aug 2024     32.74   30.19   31.30   1.9
# 16 Jul 2024     31.75   29.36   30.45   0.7
# 14 Jun 2024     30.85   28.19   30.08   0.9
#
# [*Volume Index of 1.9 means volume for the month was 1.9 times its 12-month average]
#
# [VWAP is defined as the Volume Weighted Average Price; High Low prices and VWAP are shown in US Dollars]
#
# INDEX
#
# SECTION 1 THE PAST QUARTER: NEWS AND BUZZ
#
# SECTION 2 TODAY'S BULLISH SIGNALS
#
# SECTION 3 ONGOING BULLISH PARAMETERS
#
# SECTION 4 TODAY'S BEARISH SIGNALS
#
# SECTION 5 ONGOING BEARISH PARAMETERS
#
# DATA & ARCHIVE DOWNLOAD CENTER
#
# LNSTY ADR: EXPORT DATA TO EXCEL:
#
# + SHAREHOLDERS - COMPLETE LIST OF 12 INSTITUTIONS [http://www.buysellsignals.com/bst/003991701001608243895]
#
# LNSTY ADR: OTHER INFORMATION:
#
# + NEWS ARCHIVES - LNSTY PAST 4 YEARS IN HTML: [http://www.buysellsignals.com/bst/006061701001608243895]
#
# + PRICE VOLUME CHARTS [http://www.buysellsignals.com/bst/008991701001608243895]
#
# LSEG: EXPORT DATA TO EXCEL:
#
# + PRICE VOLUME - 5-YEAR HISTORY [http://www.buysellsignals.com/bst/001061831001608241952]
#
# + FINANCIALS - 10-YEAR HISTORY [INCLUDING FY 2023]: [http://www.buysellsignals.com/bst/002061831001608241952]
#
# + PEER COMPARISON [http://www.buysellsignals.com/bst/004991831001608241952]
#
# LSEG: OTHER INFORMATION:
#
# + NEWS ARCHIVES - LSEG PAST 4 YEARS: [http://www.buysellsignals.com/bst/006991831001608241952]
#
# + PRICE VOLUME CHARTS [http://www.buysellsignals.com/bst/008991831001608241952]
#
# SECTION 1 THE PAST QUARTER: NEWS AND BUZZ
#
# 1.1 Stock Buzz
#
# Source: Other Publishers
#
# Jul      Headline                                                                            Publisher
# Mon 08   Rumble Sends Letter to London Stock Exchange CEO Regarding Russell 3000 Exclusion   Yahoo Finance
#
# SECTION 2 TODAY'S BULLISH SIGNALS
#
# 2.1 PAST WEEK: STRONG MOMENTUM UP
#
# LNSTY increases 3.2% on robust volume 1.6 times average. Compared with the BNY Mellon Composite ADR Index which rose 6.7 points (or 3.7%) in the week, the relative price change was -0.5%.
#
# Week 33 of 2024: Up 3.2%; the price ranged between a high of $32.69 on Friday Aug 16 and a low of $32.03 on Monday Aug 12.[Volume Index (VI); 1 is average]
#
# 2.2 Rank in the top 24% by Price Performance in the International Depository Receipts market
#
# Description              Value   Rank
# 1-month Price Change %   5.3     In Top 22%
# Price/MAP50              1.06    In Top 24%
#
# 2.3 Uptrend
#
# Price/Moving Average Price of 1.12 and positive MACD:
#
# - The Price/MAP 200 for London Stock Exchange is 1.12. Being higher than 1 is a bullish indicator. It is higher than the Price/MAP 200 for the BNY Mellon Composite ADR Index of 1.08, a second bullish indicator. The stock is trading above both its MAPs and the 50-day MAP of $30.74 is higher than the 200-day MAP of $29.13, a third bullish indicator. The 200-day MAP has increased to $29.13, a fourth bullish indicator.
#
# - The Moving Average Convergence Divergence (MACD) indicator of 12-day Exponential Moving Average (EMA) of 31.85 minus the 26-day EMA of 31.33 is positive, suggesting a bullish signal. Both the 12-day EMA as well as the 26-day EMA are rising, another bullish signal.
#
# - The price to 50-day EMAP ratio is 1.1, a bullish indicator. The 50-day EMAP has increased to $30.83. An increase is another bullish indicator.
#
# Past Quarter:
#
# - In the last three months the ADR has hit a new 52-week high thirteen times, pointing to a significant uptrend.
#
# The Best 3 weeks in the past quarter
#
# In the past quarter the week beginning Monday May 13 saw the highest weekly rise of 3.9% for a relative price increase of 2%.
#
# Mon-Fri     Change %   *Index Change %   Vol Ind [1 is avg]
# May 13-17   3.9        1.9               0.6
# Aug 12-16   3.2        3.7               1.6
# Jun 03-07   2.5        0.7               0.9
#
# *The Bank of New York Mellon Composite ADR Index Change %
#
# Relative Strength (6 months) 82 percentile:
#
# - The ADR has a 6-month relative strength of 82 in the International Depository Receipts market of 1,072 ADRs which means it is beating 82% of the market.
#
# - A price rise combined with a high relative strength is a bullish signal.
#
# SECTION 3 ONGOING BULLISH PARAMETERS
#
# 3.1 Past two-years
#
# - The shares rose 98.61c (4.0%) a year ago which accelerated to $6.79 (26.2%) in the past year.
#
# 3.2 Rank in the top 17% by Size in the International Depository Receipts market
#
# Description          Value           Rank
# Ave daily Turnover   $22.2 million   In Top 17%
#
# 3.3 Present Value of $1000 Invested in the Past [3 Mo, 1 Yr, 3 Yrs]; The Best Periods with PV$1000 > 1,115
#
# PV$1,000                                3 mo ago   1 yr ago   3 yrs ago
# LNSTY.OT                                $1,116     $1,260     $1,277
# Diversified Financial Services sector   $1,019     $1,125     $3,917
# BNY Mellon Composite ADR Index          $1,021     $1,223     $1,122
#
# London Stock Exchange adds 9% in 2024
#
# London Stock Exchange (OT:LNSTY), added $2.68 (or 8.9%) year-to-date (YTD) in 2024 to close at $32.66 today. Compared with the BNY Mellon Composite ADR Index which has risen 12.7% YTD, this is a relative price change of -3.8%.
#
# London Stock Exchange climbs 26% in past year
#
# London Stock Exchange (OT:LNSTY), climbed $6.71 (or 25.8%) in the past year to close at $32.66 today. Compared with the BNY Mellon Composite ADR Index which has risen 21.4% over the same period, this is a relative price increase of 4.5%.
#
# London Stock Exchange lifts 65% in 5 years
#
# London Stock Exchange (OT:LNSTY), has lifted $12.90 (or 65.3%) in the past five years to close at $32.66 today. Compared with the BNY Mellon Composite ADR Index which has risen 42.3% over the same period, this is a relative price increase of 23.0%.
#
# 3.4 The Best Periods [3 Mo, 1 Yr, 3 Yrs] with Price Change % > 11
#
# 3-Year price change of 22.3% for London Stock Exchange outperformed the change of 10.9% in the The Bank of New York Mellon Composite ADR Index for a relative price change of 11.4%.
#
# Price Change %                                    Quarter   Year   3 Years
# London Stock Exchange                             11.1      26     22.3
# Diversified Financial Services sector             1.9       12.5   298.1
# The Bank of New York Mellon Composite ADR Index   0.8       21.4   10.9
#
# 3.5 Moving Annual Return of 27.9% in the past year:
#
# Moving Annual Return was 27.9% in the past year. Based on a dynamic start date of 5 years ago, the real rate of return has averaged 13.3%. The Moving Annual Return has been positive in 3 of the last 5 years.
#
# LNSTY       Close ($)   Dividends ($)   Capital Gain / (Loss) %   % Yield   Annual Return %
# Aug 16      32.69       0.5             26                        1.9       27.9
# 1 Yr ago    25.95       0.44            4                         1.8       5.7
# 2 Yrs ago   24.97       0.32            (6.6)                     1.2       (5.4)
# 3 Yrs ago   26.73       0.25            (2.1)                     0.9       (1.2)
# 4 Yrs ago   27.31       0.22            38.2                      1.1       39.3
#
# Close 5 years ago $19.76
#
# 3.6 Annualised Period-based Total ADRholder Returns [TSR %]: The Best Periods with TSR > 8.3%
#
# TSR %      1 yr   3 yrs   5 yrs
# LNSTY.OT   26     8.4     12
#
# 3.7 Safe Interest Cover
#
# Interest cover of 4.6 is above a safe benchmark figure of 3. However, it has decreased from 6.7 a year ago.
#
# Years   Interest cover
# 2023    4.57
# 2022    6.72
# 2021    5.12
# 2020    7.47
# 2019    7.45
#
# 3.8 Low Debt to Equity (%)
#
# The debt to equity ratio of 37.4% is under a safe benchmark figure of 50%. However, it has deteriorated in the past two years.
#
# Years      Debt to Equity (%)
# Dec 2023   37.38
# Dec 2022   31.34
# Dec 2021   29.99
# Dec 2020   47.3
# Dec 2019   54.85
#
# 3.9 Increased Volume, up 20% in 5 years
#
# In the past five years, Average Daily Volume of Trading (ADVT) has increased 19.7% to 197,279 ADRs.
#
# Avg. Daily Volume Traded 12 months ended Aug 16, thousand ADRs
#
# Year   ADVT
# 2024   197.3
# 2023   257.0
# 2022   299.1
# 2021   240.7
# 2020   164.8
#
# 3.10 Increased VWAP, up 32% in 5 years
#
# In the past five years Volume Weighted Average Price (VWAP) has increased by 31.7% to $28.58.
#
# Past five years, 12 months ended Aug 16 (USD)
#
# Year   High Price   VWAP    Low Price
# 2024   32.74        28.58   24.35
# 2023   28.14        23.03   19.57
# 2022   27.74        23.46   19.46
# 2021   33.48        26.49   22.66
# 2020   30.62        21.7    15.53
#
# 3.11 Increased ADR turnover, up 57% in 5 years
#
# In the past five years, average daily ADR turnover has increased 57.1% to $5.6 million. This suggests increased liquidity.
#
# Past five years, 12 months ended Aug 16 (USD million)
#
# Year   Average Daily Turnover
# 2024   5.6
# 2023   5.9
# 2022   6.1
# 2021   6.4
# 2020   3.6
#
# SECTION 4 TODAY'S BEARISH SIGNALS
#
# 4.1 Rank in the bottom 21% by Relative Valuation in the International Depository Receipts market
#
# Description        Value   Rank
# Dividend Yield %   1.5%    In Bottom 21%
#
# 4.2 Downtrend
#
# Today's Volatility:
#
# The 0.1% discount to 12-month high of $32.74 against the 34% premium to 12-month low of $24.35 suggests the climb might be peaking.
#
# 4.3 Overbought/Bearish Signals:
#
# - The ADR is overbought according to the Williams % R indicator of -2.0, suggesting the price is close to its 14-day high of $32.74.
#
# SECTION 5 ONGOING BEARISH PARAMETERS
#
# 5.1 Rank in the bottom 19% by Size in the International Depository Receipts market
#
# Description   Value         Rank
# MCap          $69 billion   In Bottom 19%
#
# 5.2 EPS growth [FY2023 vs FY2022] of -40.6%:
#
# FY     EPS (GBP)   Growth %
# 2023   1.39        -40.6
# 2022   2.34        -59.8

# %% [markdown]
# ### Close the session

# %%
ld.close_session()
