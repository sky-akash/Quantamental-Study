# %% [markdown]
# ----
# <img src="../../files/lseg.svg" class="rft-examples-logo" width="20%" style="vertical-align: top;">
#
# # Data Library for Python
#
# ----

# %% [markdown]
# ## Access layer - Search templates examples - Equity Search
#
# This notebook illustrates the Search Template functionality of the LSEG Data Library. The "Equity" template shown here are template examples that you can modify and adapt to your needs. They are defined in the "search-templates.config.json" configuration file. Below is a brief description of the parameters you can use for each template definition.

# %% [markdown]
# **Search templates are defined using the following JSON structure:**
#
# - **description** (string): Description of the template.
# - **parameters** (object): Parameters of the template. These parameters can be used as placeholders in the request_body of the template and as named parameters of the search() method of the template. Each parameter has a name, a description, and an optional default value.
# - **request_body** (object): Body of the request sent to the Search REST API. This request body can include template parameters surrounded by '#{' and '}' (for example:  “#{my_param}”). More details on the structure of the request body can be found in the [Search API reference guide](https://apidocs.refinitiv.com/Apps/ApiDocs#/details/L2Rpc2NvdmVyeS9zZWFyY2gvdjE=/Lw==/POST/README) (access to this guide requires a LSEG Workspace account or RDP account to log in).
#
# **Template example:**
#
# ```json
# "MyTemplate": {
#     "description": "Search template example.",
#     "parameters": {
#         "name": {
#             "description": "Name of the person to search for.",
#             "default": "Edison"
#         }
#     },
#     "request_body": {
#        "Query": "#{name}",
#        "View":"People",
#        "Top":10
#     }
# }
# ```
#
# **Example of usage:**
#
# ```
# ld.discovery.search_templates["MyTemplate"].search(name="Pasteur")
# ```

# %% [markdown]
# #### Learn more
#
# To learn more about the LSEG Data Library for Python please join the LSEG Developer Community. By [registering](https://developers.lseg.com/iam/register) and [logging](https://developers.lseg.com/content/devportal/en_us/initCookie.html) into the LSEG Developer Community portal you will have free access to a number of learning materials like
#  [Quick Start guides](https://developers.lseg.com/en/api-catalog/lseg-data-platform/lseg-data-library-for-python/quick-start),
#  [Tutorials](https://developers.lseg.com/en/api-catalog/lseg-data-platform/lseg-data-library-for-python/tutorials),
#  [Documentation](https://developers.lseg.com/en/api-catalog/lseg-data-platform/lseg-data-library-for-python/documentation)
#  and much more.
#
# #### Getting Help and Support
#
# If you have any questions regarding using the API, please post them on
# the [Data Library Q&A Forum](https://community.developers.refinitiv.com/smart-spaces/521/index.html).
# The LSEG Developer Community will be happy to help.
#
# ----

# %% [markdown]
# ## Some Imports to start with

# %%
import lseg.data as ld
import cufflinks
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Extra configuration of `cufflinks` lib to not use online services

# %%
cufflinks.set_config_file(offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ## Open the data session
#
# The open_session() function creates and open sessions based on the information contained in the lseg-data.config.json configuration file. Please edit this file to set the session type and other parameters required for the session you want to open.

# %%
ld.open_session()
# Out:
# <lseg.data.session.Definition object at 0x31bf87eb0 {name='workspace'}>

# %% [markdown]
# ## Load the search templates configuration file

# %%
ld.load_config("search-templates.config.json")
# Out:
# <ConfigurationSet: 0x106218e80>

# %% [markdown]
# ## Equities Search Template example

# %% [markdown]
# ### Access the template

# %%
equity = ld.discovery.search_templates["Equity"]

# %% [markdown]
# ### Get help about this template

# %%
help(equity)
# Out:
# Help on DiscoverySearchTemplate in module lseg.data.discovery._search_templates.search:
#
# <DiscoverySearchTemplate 'Equity'>
#     Search for Ordinary Shares of a particular exchange.
#
#     Methods
#     -------
#     search
#         exchange_name
#             Name of the exchange where this equity is traded. For example: 'London Stock Exchange', 'Euronext Paris', 'Shanghai Stock Exchange', 'The Toronto Stock Exchange', 'NYSE Consolidated', etc.
#
#         what
#             What to search for
#             default: ''

# %% [markdown]
# ### Use the predefined parameters of the template to search for Equities of the London Stock Exchange

# %%
lse_equities = equity.search(exchange_name="London Stock Exchange")
display(lse_equities)
# Out:
# /Users/h.aramyan/Library/Python/3.9/lib/python/site-packages/lseg/data/content/search/_data_provider.py:298: UserWarning:
#
# Search result for  not full.
# Result is maxed at 10000 while the total is 18143 rows.
# Requested - 10000, skipped - 0 rows.
#                             DTSubjectName           ExchangeName  \
# 0               Flutter Entertainment PLC  London Stock Exchange
# 1                               Shell PLC  London Stock Exchange
# 2                         AstraZeneca PLC  London Stock Exchange
# 3                            Glencore PLC  London Stock Exchange
# 4                            Unilever PLC  London Stock Exchange
# ...                                   ...                    ...
# 9995                Japan Steel Works Ltd  London Stock Exchange
# 9996                             Bpost SA  London Stock Exchange
# 9997       Navidea Biopharmaceuticals Inc  London Stock Exchange
# 9998     Prestige Consumer Healthcare Inc  London Stock Exchange
# 9999  China Longyuan Power Group Corp Ltd  London Stock Exchange
#
#                    RIC  MktCapCompanyUsd  ShareholdersEquityUsd         Pe  \
# 0              FLTRF.L       37576087946            10044000000       <NA>
# 1               SHEL.L      212290767376           186607000000  11.569129
# 2                AZN.L      265797468666            39143000000  39.648424
# 3               GLEN.L       61058140900            43580000000       <NA>
# 4               ULVR.L      162367344912            20060636400  22.080266
# ...                ...               ...                    ...        ...
# 9995          J9Rf.TRE        2189251775             1216635732       <NA>
# 9996       BPOSTbr.TRE         574050309             1138121400       <NA>
# 9997         NO1Af.TRE            100084               -8435840       <NA>
# 9998  US74112D1019.TRE        3741581510             1655084000       <NA>
# 9999          6WXf.TRE       12771072008             9959115844       <NA>
#
#       DebtToAssets      Beta        Eps  \
# 0         0.538543  0.850373  -7.477555
# 1         0.536363  1.265271    2.82199
# 2         0.612674  0.391883    4.15975
# 3         0.691311  2.025295   -0.04344
# 4         0.724125   0.42927     2.6519
# ...            ...       ...        ...
# 9995      0.513018      <NA>  209.91919
# 9996      0.750777      <NA>    0.24468
# 9997      2.862769      <NA>   -0.21338
# 9998      0.501243      <NA>    4.08693
# 9999      0.640895      <NA>    0.74662
#
#                                                    Gics  ...  \
# 0     Consumer Discretionary/Consumer Services/Hotel...  ...
# 1     Energy/Energy/Oil, Gas & Consumable Fuels/Inte...  ...
# 2     Health Care/Pharmaceuticals, Biotechnology & L...  ...
# 3     Materials/Materials/Metals & Mining/Diversifie...  ...
# 4     Consumer Staples/Household & Personal Products...  ...
# ...                                                 ...  ...
# 9995  Industrials/Capital Goods/Machinery/Industrial...  ...
# 9996  Industrials/Transportation/Air Freight & Logis...  ...
# 9997  Health Care/Pharmaceuticals, Biotechnology & L...  ...
# 9998  Health Care/Pharmaceuticals, Biotechnology & L...  ...
# 9999  Utilities/Utilities/Independent Power and Rene...  ...
#
#       RCSAssetCategory  RCSCurrencyLeaf  AssetState  BusinessEntity  \
# 0                 A:1L    British Penny          AC    QUOTExEQUITY
# 1                 A:1L    British Penny          AC    QUOTExEQUITY
# 2                 A:1L    British Penny          AC    QUOTExEQUITY
# 3                 A:1L    British Penny          AC    QUOTExEQUITY
# 4                 A:1L    British Penny          AC    QUOTExEQUITY
# ...                ...              ...         ...             ...
# 9995              A:1L             Euro          AC    QUOTExEQUITY
# 9996              A:1L             Euro          AC    QUOTExEQUITY
# 9997              A:1L             Euro          AC    QUOTExEQUITY
# 9998              A:1L        US Dollar          AC    QUOTExEQUITY
# 9999              A:1L             Euro          AC    QUOTExEQUITY
#
#              PI     IssueISIN   CinCUSIP    SEDOL      CUSIP  SolvencyMargin
# 0       7626029  IE00BWT6H894  G3643J108  BWXC0Z1       <NA>            <NA>
# 1      21264014  GB00BP6MXD84  G80827101  BP6MXD8       <NA>            <NA>
# 2       1049533  GB0009895292  G0593M107  0989529       <NA>            <NA>
# 3      86386483  JE00B4T3BW64  G39420107  B4T3BW6       <NA>            <NA>
# 4       1049434  GB00B10RZP78  G92087165  B10RZP7       <NA>            <NA>
# ...         ...           ...        ...      ...        ...             ...
# 9995  330993428  JP3721400004  J27743129     <NA>       <NA>            <NA>
# 9996  279340758  BE0974268972  B1306V108     <NA>       <NA>            <NA>
# 9997  668388078  US63937X2027       <NA>     <NA>  63937X202            <NA>
# 9998  702758564  US74112D1019       <NA>     <NA>  74112D101            <NA>
# 9999  780052119  CNE100000HD4  Y1501T101     <NA>       <NA>            <NA>
#
# [10000 rows x 45 columns]

# %% [markdown]
# ### Experiment with the returned DataFrame

# %% [markdown]
# #### Define a function to plot and display data

# %%
def plot_and_display(df, column_name):
    df = df.sort_values(column_name,ascending = False)
    df[['DTSubjectName', column_name]].iplot(x='DTSubjectName')
    display(df)

# %% [markdown]
# #### Get the Equities by Market Cap

# %%
equities = lse_equities.query("MktCapCompanyUsd >= 30_000_000_000")
plot_and_display(equities, "MktCapCompanyUsd")
# Out:
# <div>                            <div id="845346ef-bf55-4db8-9b25-be0ef838cc0d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("845346ef-bf55-4db8-9b25-be0ef838cc0d")) {                    Plotly.newPlot(                        "845346ef-bf55-4db8-9b25-be0ef838cc0d",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"MktCapCompanyUsd","text":"","x":["Apple Inc","Apple Inc","Microsoft Corp","Microsoft Corp","NVIDIA Corp","NVIDIA Corp","Alphabet Inc","Alphabet Inc","Alphabet Inc","Alphabet Inc","Amazon.com Inc","Amazon.com Inc","Meta Platforms Inc","Meta Platforms Inc","Berkshire Hathaway Inc","Berkshire Hathaway Inc","Berkshire Hathaway Inc","Berkshire Hathaway Inc","Eli Lilly and Co","Eli Lilly and Co","Broadcom Inc","Broadcom Inc","Tesla Inc","Tesla Inc","JPMorgan Chase & Co","JPMorgan Chase & Co","Walmart Inc","Walmart Inc","Unitedhealth Group Inc","Unitedhealth Group Inc","Visa Inc","Visa Inc","Exxon Mobil Corp","Exxon Mobil Corp","Novo Nordisk A\u002fS","Novo Nordisk A\u002fS","Tencent Holdings Ltd","Tencent Holdings Ltd","Mastercard Inc","Mastercard Inc","Procter & Gamble Co","Johnson & Johnson","Johnson & Johnson","Costco Wholesale Corp","Costco Wholesale Corp","Oracle Corp","Oracle Corp","Home Depot Inc","Home Depot Inc","LVMH Moet Hennessy Louis Vuitton SE","LVMH Moet Hennessy Louis Vuitton SE","AbbVie Inc","AbbVie Inc","ASML Holding NV","ASML Holding NV","Bank of America Corp","Bank of America Corp","Coca-Cola Co","Coca-Cola Co","Merck & Co Inc","Netflix Inc","Netflix Inc","Toyota Motor Corp","Toyota Motor Corp","Nestle SA","Nestle SA","Nestle SA","Roche Holding AG","AstraZeneca PLC","AstraZeneca PLC","SAP SE","SAP SE","Novartis AG","Novartis AG","Chevron Corp","Chevron Corp","Adobe Inc","Adobe Inc","PepsiCo Inc","PepsiCo Inc","Hermes International SCA","Hermes International SCA","Salesforce Inc","Salesforce Inc","Thermo Fisher Scientific Inc","L'Oreal SA","L'Oreal SA","T-Mobile US Inc","T-Mobile US Inc","Advanced Micro Devices Inc","Advanced Micro Devices Inc","Linde PLC","Linde PLC","Accenture PLC","Accenture PLC","Shell PLC","Shell PLC","McDonald's Corp","McDonald's Corp","China Mobile Ltd","Cisco Systems Inc","Cisco Systems Inc","Abbott Laboratories","Abbott Laboratories","Alibaba Group Holding Ltd","Wells Fargo & Co","Wells Fargo & Co","Philip Morris International Inc","Philip Morris International Inc","Danaher Corp","Danaher Corp","International Business Machines Corp","International Business Machines Corp","Texas Instruments Inc","Texas Instruments Inc","Qualcomm Inc","Qualcomm Inc","General Electric Co","American Express Co","American Express Co","Amgen Inc","Amgen Inc","Intuit Inc","Intuit Inc","Verizon Communications Inc","Verizon Communications Inc","Royal Bank of Canada","Royal Bank of Canada","ServiceNow Inc","ServiceNow Inc","Intuitive Surgical Inc","Blackstone Inc","Nextera Energy Inc","Nextera Energy Inc","Industria de Diseno Textil SA","Industria de Diseno Textil SA","Caterpillar Inc","Caterpillar Inc","Unilever PLC","Unilever PLC","Morgan Stanley","Walt Disney Co","Walt Disney Co","RTX Corp","RTX Corp","Pfizer Inc","Pfizer Inc","S&P Global Inc","TotalEnergies SE","HSBC Holdings PLC","HSBC Holdings PLC","Union Pacific Corp","Union Pacific Corp","Goldman Sachs Group Inc","Goldman Sachs Group Inc","Applied Materials Inc","Applied Materials Inc","Uber Technologies Inc","Uber Technologies Inc","Uber Technologies Inc","Comcast Corp","Comcast Corp","Progressive Corp","Progressive Corp","Sanofi SA","Sanofi SA","Siemens AG","Siemens AG","AT&T Inc","AT&T Inc","Deutsche Telekom AG","Schneider Electric SE","Schneider Electric SE","Lowe's Companies Inc","Lowe's Companies Inc","Stryker Corp","Stryker Corp","Lockheed Martin Corp","Lockheed Martin Corp","TJX Companies Inc","TJX Companies Inc","BHP Group Ltd","BHP Group Ltd","BHP Group Ltd","BlackRock Inc","BlackRock Inc","Regeneron Pharmaceuticals Inc","Mitsubishi UFJ Financial Grou ...
#           DTSubjectName           ExchangeName         RIC  MktCapCompanyUsd  \
# 2792          Apple Inc  London Stock Exchange   APCde.TRE     3357833656450
# 1677          Apple Inc  London Stock Exchange      0R2V.L     3357833656450
# 2794     Microsoft Corp  London Stock Exchange   MSFde.TRE     3039369393990
# 1678     Microsoft Corp  London Stock Exchange      0QYP.L     3039369393990
# 2793        NVIDIA Corp  London Stock Exchange   NVDde.TRE     2605331300000
# ...                 ...                    ...         ...               ...
# 7247  Brown & Brown Inc  London Stock Exchange    BTWf.TRE       30186318596
# 9338        Aena SME SA  London Stock Exchange  AENAmc.TRE       30087630000
# 5313        Aena SME SA  London Stock Exchange      0R4Y.L       30087630000
# 32    Ashtead Group PLC  London Stock Exchange       AHT.L       30030702157
# 7540  Ashtead Group PLC  London Stock Exchange    AHTl.TRE       30030702157
#
#       ShareholdersEquityUsd         Pe  DebtToAssets      Beta       Eps  \
# 2792            62146000000       <NA>      0.823741      <NA>   6.56791
# 1677            62146000000  33.191685      0.823741  0.703971   6.56791
# 2794           268477000000       <NA>      0.475798      <NA>  11.79988
# 1678           268477000000  34.661369      0.475798  0.279005  11.79988
# 2793            42978000000       <NA>      0.346123      <NA>  2.129082
# ...                     ...        ...           ...       ...       ...
# 7247             5578800000       <NA>      0.625166      <NA>   3.47381
# 9338                   <NA>       <NA>          <NA>      <NA>  12.21222
# 5313                   <NA>       <NA>          <NA>      <NA>  12.21222
# 32               7084600000  18.880115      0.672786  1.479067   3.55853
# 7540             7084600000       <NA>      0.672786      <NA>   3.55853
#
#                                                    Gics  ...  \
# 2792  Information Technology/Technology Hardware & E...  ...
# 1677  Information Technology/Technology Hardware & E...  ...
# 2794  Information Technology/Software & Services/Sof...  ...
# 1678  Information Technology/Software & Services/Sof...  ...
# 2793  Information Technology/Semiconductors & Semico...  ...
# ...                                                 ...  ...
# 7247   Financials/Insurance/Insurance/Insurance Brokers  ...
# 9338  Industrials/Transportation/Transportation Infr...  ...
# 5313  Industrials/Transportation/Transportation Infr...  ...
# 32    Industrials/Capital Goods/Trading Companies & ...  ...
# 7540  Industrials/Capital Goods/Trading Companies & ...  ...
#
#       RCSAssetCategory  RCSCurrencyLeaf  AssetState  BusinessEntity  \
# 2792              A:1L        US Dollar          AC    QUOTExEQUITY
# 1677              A:1L        US Dollar          AC    QUOTExEQUITY
# 2794              A:1L        US Dollar          AC    QUOTExEQUITY
# 1678              A:1L        US Dollar          AC    QUOTExEQUITY
# 2793              A:1L        US Dollar          AC    QUOTExEQUITY
# ...                ...              ...         ...             ...
# 7247              A:1L             Euro          AC    QUOTExEQUITY
# 9338              A:1L             Euro          AC    QUOTExEQUITY
# 5313              A:1L             Euro          AC    QUOTExEQUITY
# 32                A:1L    British Penny          AC    QUOTExEQUITY
# 7540              A:1L    British Penny          AC    QUOTExEQUITY
#
#              PI     IssueISIN   CinCUSIP    SEDOL      CUSIP  SolvencyMargin
# 2792  285519007  US0378331005       <NA>     <NA>  037833100            <NA>
# 1677  285518846  US0378331005       <NA>  B0YQ5W0  037833100            <NA>
# 2794  285519023  US5949181045       <NA>     <NA>  594918104            <NA>
# 1678  285518884  US5949181045       <NA>  B10RVH1  594918104            <NA>
# 2793  285519026  US67066G1040       <NA>     <NA>  67066G104            <NA>
# ...         ...           ...        ...      ...        ...             ...
# 7247  333613146  US1152361010       <NA>     <NA>  115236101            <NA>
# 9338  279333576  ES0105046009  E526K0106     <NA>       <NA>            <NA>
# 5313  181983810  ES0105046009  E526K0106  BVYV3F1       <NA>            <NA>
# 32      1081144  GB0000536739  G05320109  0053673       <NA>            <NA>
# 7540  279347927  GB0000536739  G05320109     <NA>       <NA>            <NA>
#
# [770 rows x 45 columns]

# %%
equities = lse_equities.query("Beta >= 3")
plot_and_display(equities, "Beta")
# Out:
# <div>                            <div id="e71f1181-f34c-45b9-969f-3c5ced484500" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("e71f1181-f34c-45b9-969f-3c5ced484500")) {                    Plotly.newPlot(                        "e71f1181-f34c-45b9-969f-3c5ced484500",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"Beta","text":"","x":["Finseta PLC","musicMagpie PLC","Genflow Biosciences PLC","Costain Group PLC","XP Factory Plc","Harbour Energy PLC","Alkemy Capital Investments PLC","Revolution Bars Group PLC","Kanabo Group PLC","Kosmos Energy Ltd","Pineapple Power Corporation PLC","Predator Oil & Gas Holdings PLC","Petra Diamonds Ltd","Iconic Labs PLC","N Brown Group PLC","Tullow Oil PLC","Hammerson PLC","Card Factory PLC","Huddled Group PLC","Ageas SA","Carnival PLC","ASOS PLC","Capita PLC","SIG PLC","Saga PLC","Echo Energy PLC","Amigo Holdings PLC","Pharos Energy PLC","Biome Technologies PLC","Jet2 PLC","Easyjet PLC","Vistry Group PLC","Eneraqua Technologies PLC","Sosandar PLC","International Consolidated Airlines Group SA","AFC Energy PLC","Rank Group PLC","Elementis PLC","Virgin Money UK PLC","Tekmar Group PLC","Staffline Group PLC","THG PLC","XLMedia PLC","Gattaca PLC","Crest Nicholson Holdings PLC","Gran Tierra Energy Inc","Inspirit Energy Holdings PLC"],"y":[4.815448,4.719238,4.490683,4.372814,4.336909,4.200978,4.10827,4.091526,4.07447,3.989803,3.988794,3.94192,3.921661,3.890924,3.806615,3.797577,3.765236,3.759839,3.735268,3.660706,3.645032,3.586346,3.485323,3.475511,3.4326,3.431534,3.425432,3.326351,3.324084,3.264777,3.253652,3.241326,3.238359,3.226084,3.220261,3.181749,3.168387,3.096067,3.086681,3.078853,3.077055,3.074624,3.055161,3.047521,3.038832,3.014882,3.009742],"type":"scatter"}],                        {"legend":{"bgcolor":"#F5F6F9","font":{"color":"#4D5663"}},"paper_bgcolor":"#F5F6F9","plot_bgcolor":"#F5F6F9","template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8 ...
#                                      DTSubjectName           ExchangeName  \
# 855                                    Finseta PLC  London Stock Exchange
# 1210                               musicMagpie PLC  London Stock Exchange
# 1342                       Genflow Biosciences PLC  London Stock Exchange
# 321                              Costain Group PLC  London Stock Exchange
# 885                                 XP Factory Plc  London Stock Exchange
# 130                             Harbour Energy PLC  London Stock Exchange
# 1082                Alkemy Capital Investments PLC  London Stock Exchange
# 758                      Revolution Bars Group PLC  London Stock Exchange
# 1274                              Kanabo Group PLC  London Stock Exchange
# 2716                             Kosmos Energy Ltd  London Stock Exchange
# 1516               Pineapple Power Corporation PLC  London Stock Exchange
# 849                Predator Oil & Gas Holdings PLC  London Stock Exchange
# 1209                            Petra Diamonds Ltd  London Stock Exchange
# 842                                Iconic Labs PLC  London Stock Exchange
# 945                              N Brown Group PLC  London Stock Exchange
# 290                                 Tullow Oil PLC  London Stock Exchange
# 151                                  Hammerson PLC  London Stock Exchange
# 384                               Card Factory PLC  London Stock Exchange
# 1321                             Huddled Group PLC  London Stock Exchange
# 1790                                      Ageas SA  London Stock Exchange
# 146                                   Carnival PLC  London Stock Exchange
# 415                                       ASOS PLC  London Stock Exchange
# 353                                     Capita PLC  London Stock Exchange
# 634                                        SIG PLC  London Stock Exchange
# 694                                       Saga PLC  London Stock Exchange
# 676                                Echo Energy PLC  London Stock Exchange
# 522                             Amigo Holdings PLC  London Stock Exchange
# 916                              Pharos Energy PLC  London Stock Exchange
# 1199                        Biome Technologies PLC  London Stock Exchange
# 136                                       Jet2 PLC  London Stock Exchange
# 74                                     Easyjet PLC  London Stock Exchange
# 75                                Vistry Group PLC  London Stock Exchange
# 1120                     Eneraqua Technologies PLC  London Stock Exchange
# 564                                   Sosandar PLC  London Stock Exchange
# 33    International Consolidated Airlines Group SA  London Stock Exchange
# 592                                 AFC Energy PLC  London Stock Exchange
# 613                                 Rank Group PLC  London Stock Exchange
# 383                                  Elementis PLC  London Stock Exchange
# 191                            Virgin Money UK PLC  London Stock Exchange
# 1330                              Tekmar Group PLC  London Stock Exchange
# 988                            Staffline Group PLC  London Stock Exchange
# 296                                        THG PLC  London Stock Exchange
# 1076                                   XLMedia PLC  London Stock Exchange
# 984                                    Gattaca PLC  London Stock Exchange
# 272                   Crest Nicholson Holdings PLC  London Stock Exchange
# 2679                        Gran Tierra Energy Inc  London Stock Exchange
# 1167                  Inspirit Energy Holdings PLC  London Stock Exchange
#
#            RIC  MktCapCompanyUsd  ShareholdersEquityUsd          Pe  \
# 855      FIN.L          29805733                2175710   10.635433
# 1210    MMAG.L           8146694               16133119        <NA>
# 1342    GENF.L          10340649                 954004        <NA>
# 321     COSG.L         381958132              288335480    9.277344
# 885      XPF.L          31651416               28382777        <NA>
# 130      HBR.L        6295784117             1553000000   29.384557
# 1082  ALKALK.L           5213014                -684238        <NA>
# 758      RBG.L          17223774              -59627882        <NA>
# 1274     KNB.L          10804777                9873584        <NA>
# 2716     KOS.L        2057120685                   <NA>    8.060035
# 1516    PNPL.L           3000740                 188771        <NA>
# 849     PRDP.L          74210118               27478344        <NA>
# 1209     PDL.L          68016126              320700000        <NA>
# 842    ICONI.L            770092               -4783556        <NA>
# 945     BWNG.L         143807320              498213220  134.482759
# 290      TLW.L         468737678             -359400000   30.227109
# 151     HMSO.L        1872645500             3236348920        <NA>
# 384    CARDC.L         558243486              415024360    8.480811
# 1321    HUDH.L          13474296               13538888        <NA>
# 1790    0Q99.L        9678067241             8225060400        <NA>
# 146      CCL.L        2136163821             6882000000        <NA>
# 415     ASOS.L         576504105             1139017140        <NA>
# 353      CPI.L         406023761              148504600        <NA>
# 634      SHI.L         375001726              300294700        <NA>
# 694     SAGA.L         191350928                   <NA>        <NA>
# 676    ECHOE.L           2064889               -7621010        <NA>
# 522     AMGO.L           3935178                      0        <NA>
# 916    PHARP.L         136652263              273500000        <NA>
# 1199    BIOM.L           2718957                 988278        <NA>
# 136     JET2.L        4105100852             1851576380    7.826199
# 74       EZJ.L        4786629403             3662675400     9.67229
# 75      VTYV.L        5779916568             4361172700   20.429991
# 1120     ETP.L          17900814               24923803        <NA>
# 564     SOSS.L          31806380               24140539        <NA>
# 33      ICAG.L       11988539028             3626030400    4.092718
# 592     AFEN.L         140086788               40851907        <NA>
# 613      RNK.L         451857815              427509260   27.951257
# 383      ELM.L        1227857581              847300000        <NA>
# 191     VMUK.L        3673445414             7368719400   11.390533
# 1330    TGPT.L          17138019               45540972        <NA>
# 988     STAF.L          65055131               72149580        <NA>
# 296      THG.L        1047737731             1342674771        <NA>
# 1076     XLM.L          33646377               53578000        <NA>
# 984     GATC.L          40798178               40499701   22.174696
# 272     CRST.L         678666394             1125349460        <NA>
# 2679     GTE.L         205719734                   <NA>    4.848063
# 1167    INSP.L            975264                3156708        <NA>
#
#       DebtToAssets      Beta       Eps  \
# 855         0.7546  4.815448   0.03714
# 1210      0.725523  4.719238  -0.06958
# 1342      0.322624  4.490683  -0.00554
# 321       0.531797  4.372814   0.11264
# 885       0.651155  4.336909  -0.00458
# 130       0.843384  4.200978   0.12184
# 1082      2.065051   4.10827   -0.2249
# 758       1.325163  4.091526 -0.077808
# 1274      0.101664   4.07447  -0.01374
# 2716          <NA>  3.989803   0.53642
# 1516      0.266019  3.988794  -0.00632
# 849       0.193519   3.94192  -0.01192
# 1209       0.63197  3.921661  -0.29248
# 842      73.450239  3.890924      -0.1
# 945       0.503796  3.806615   0.00174
# 290       1.080608  3.797577   0.01023
# 151       0.430981  3.765236  -0.01509
# 384       0.428002  3.759839   0.14409
# 1321      0.067692  3.735268  -0.00844
# 1790      0.912103  3.660706    5.7974
# 146       0.859894  3.645032  -0.05803
# 415       0.669904  3.586346  -2.08767
# 353       0.942487  3.485323  -0.02397
# 634       0.819638  3.475511    -0.054
# 694           <NA>    3.4326  -0.80857
# 676      16.152017  3.431534  -0.00063
# 522            1.0  3.425432   -0.0262
# 916       0.401532  3.326351   -0.1142
# 1199      0.803911  3.324084  -0.41085
# 136       0.747056  3.264777   1.85914
# 74        0.716797  3.253652   0.49678
# 75        0.454678  3.241326   0.64513
# 1120      0.600046  3.238359  -0.18982
# 564       0.328471  3.226084  -0.00259
# 33        0.913004  3.220261   0.53673
# 592       0.142199  3.181749  -0.02614
# 613       0.557729  3.168387   0.02626
# 383       0.439394  3.096067  -0.05874
# 191       0.938912  3.086681   0.18928
# 1330      0.349301  3.078853  -0.06781
# 988       0.741282  3.077055   -0.1202
# 296       0.632572  3.074624  -0.19128
# 1076      0.312212  3.055161  -0.17918
# 984       0.621301  3.047521   0.04442
# 272       0.440437  3.038832  -0.10349
# 2679          <NA>  3.014882   1.59066
# 1167      0.270131  3.009742  -0.00005
#
#                                                    Gics  ...  \
# 855   Financials/Financial Services/Financial Servic...  ...
# 1210  Consumer Discretionary/Consumer Discretionary ...  ...
# 1342  Health Care/Pharmaceuticals, Biotechnology & L...  ...
# 321   Industrials/Capital Goods/Construction & Engin...  ...
# 885   Consumer Discretionary/Consumer Services/Hotel...  ...
# 130   Energy/Energy/Oil, Gas & Consumable Fuels/Oil ...  ...
# 1082  Industrials/Capital Goods/Electrical Equipment...  ...
# 758   Consumer Discretionary/Consumer Services/Hotel...  ...
# 1274  Health Care/Pharmaceuticals, Biotechnology & L...  ...
# 2716  Energy/Energy/Oil, Gas & Consumable Fuels/Oil ...  ...
# 1516                                               <NA>  ...
# 849   Energy/Energy/Oil, Gas & Consumable Fuels/Oil ...  ...
# 1209  Materials/Materials/Metals & Mining/Precious M...  ...
# 842   Health Care/Health Care Equipment & Services/H...  ...
# 945   Consumer Discretionary/Consumer Discretionary ...  ...
# 290   Energy/Energy/Oil, Gas & Consumable Fuels/Oil ...  ...
# 151   Real Estate/Equity Real Estate Investment Trus...  ...
# 384   Consumer Discretionary/Consumer Discretionary ...  ...
# 1321  Communication Services/Media & Entertainment/E...  ...
# 1790  Financials/Insurance/Insurance/Multi-line Insu...  ...
# 146   Consumer Discretionary/Consumer Services/Hotel...  ...
# 415   Consumer Discretionary/Consumer Discretionary ...  ...
# 353   Industrials/Commercial & Professional Services...  ...
# 634   Industrials/Capital Goods/Trading Companies & ...  ...
# 694   Financials/Insurance/Insurance/Multi-line Insu...  ...
# 676   Energy/Energy/Oil, Gas & Consumable Fuels/Inte...  ...
# 522   Financials/Financial Services/Consumer Finance...  ...
# 916   Energy/Energy/Oil, Gas & Consumable Fuels/Oil ...  ...
# 1199  Materials/Materials/Chemicals/Commodity Chemicals  ...
# 136   Industrials/Transportation/Passenger Airlines/...  ...
# 74    Industrials/Transportation/Passenger Airlines/...  ...
# 75    Consumer Discretionary/Consumer Durables & App...  ...
# 1120  Industrials/Capital Goods/Building Products/Bu...  ...
# 564   Consumer Discretionary/Consumer Durables & App...  ...
# 33    Industrials/Transportation/Passenger Airlines/...  ...
# 592   Industrials/Capital Goods/Electrical Equipment...  ...
# 613   Consumer Discretionary/Consumer Services/Hotel...  ...
# 383   Materials/Materials/Chemicals/Specialty Chemicals  ...
# 191            Financials/Banks/Banks/Diversified Banks  ...
# 1330  Energy/Energy/Energy Equipment & Services/Oil ...  ...
# 988   Industrials/Commercial & Professional Services...  ...
# 296   Consumer Discretionary/Consumer Discretionary ...  ...
# 1076  Communication Services/Media & Entertainment/I...  ...
# 984   Industrials/Commercial & Professional Services...  ...
# 272   Consumer Discretionary/Consumer Durables & App...  ...
# 2679  Energy/Energy/Oil, Gas & Consumable Fuels/Oil ...  ...
# 1167  Industrials/Capital Goods/Machinery/Industrial...  ...
#
#       RCSAssetCategory  RCSCurrencyLeaf  AssetState  BusinessEntity  \
# 855               A:1L    British Penny          AC    QUOTExEQUITY
# 1210              A:1L    British Penny          AC    QUOTExEQUITY
# 1342              A:1L    British Penny          AC    QUOTExEQUITY
# 321               A:1L    British Penny          AC    QUOTExEQUITY
# 885               A:1L    British Penny          AC    QUOTExEQUITY
# 130               A:1L    British Penny          AC    QUOTExEQUITY
# 1082              A:1L    British Penny          AC    QUOTExEQUITY
# 758               A:1L    British Penny          AC    QUOTExEQUITY
# 1274              A:1L    British Penny          AC    QUOTExEQUITY
# 2716              A:1L    British Penny          AC    QUOTExEQUITY
# 1516              A:1L    British Penny          AC    QUOTExEQUITY
# 849               A:1L    British Penny          AC    QUOTExEQUITY
# 1209              A:1L    British Penny          AC    QUOTExEQUITY
# 842               A:1L    British Penny          AC    QUOTExEQUITY
# 945               A:1L    British Penny          AC    QUOTExEQUITY
# 290               A:1L    British Penny          AC    QUOTExEQUITY
# 151               A:1L    British Penny          AC    QUOTExEQUITY
# 384               A:1L    British Penny          AC    QUOTExEQUITY
# 1321              A:1L    British Penny          AC    QUOTExEQUITY
# 1790              A:1L             Euro          AC    QUOTExEQUITY
# 146               A:1L    British Penny          AC    QUOTExEQUITY
# 415               A:1L    British Penny          AC    QUOTExEQUITY
# 353               A:1L    British Penny          AC    QUOTExEQUITY
# 634               A:1L    British Penny          AC    QUOTExEQUITY
# 694               A:1L    British Penny          AC    QUOTExEQUITY
# 676               A:1L    British Penny          AC    QUOTExEQUITY
# 522               A:1L    British Penny          AC    QUOTExEQUITY
# 916               A:1L    British Penny          AC    QUOTExEQUITY
# 1199              A:1L    British Penny          AC    QUOTExEQUITY
# 136               A:1L    British Penny          AC    QUOTExEQUITY
# 74                A:1L    British Penny          AC    QUOTExEQUITY
# 75                A:1L    British Penny          AC    QUOTExEQUITY
# 1120              A:1L    British Penny          AC    QUOTExEQUITY
# 564               A:1L    British Penny          AC    QUOTExEQUITY
# 33                A:1L    British Penny          AC    QUOTExEQUITY
# 592               A:1L    British Penny          AC    QUOTExEQUITY
# 613               A:1L    British Penny          AC    QUOTExEQUITY
# 383               A:1L    British Penny          AC    QUOTExEQUITY
# 191               A:1L    British Penny          AC    QUOTExEQUITY
# 1330              A:1L    British Penny          AC    QUOTExEQUITY
# 988               A:1L    British Penny          AC    QUOTExEQUITY
# 296               A:1L    British Penny          AC    QUOTExEQUITY
# 1076              A:1L    British Penny          AC    QUOTExEQUITY
# 984               A:1L    British Penny          AC    QUOTExEQUITY
# 272               A:1L    British Penny          AC    QUOTExEQUITY
# 2679              A:1L    British Penny          AC    QUOTExEQUITY
# 1167              A:1L    British Penny          AC    QUOTExEQUITY
#
#              PI     IssueISIN   CinCUSIP    SEDOL      CUSIP  SolvencyMargin
# 855   505647007  GB00BNG7CD28  G2424B102  BNG7CD2       <NA>            <NA>
# 1210  509315483  GB00BKY4XG48  G572HZ105  BKY4XG4       <NA>            <NA>
# 1342  576910608  GB00BP2C3V08  G392AE102  BP2C3V0       <NA>            <NA>
# 321     1079935  GB00B64NSP76  G24472204  B64NSP7       <NA>            <NA>
# 885   229781424  GB00BDB79J29  G2816A100  BDB79J2       <NA>            <NA>
# 130     1080131  GB00BMBVGQ36  G4289T111  BMBVGQ3       <NA>            <NA>
# 1082  549361066  GB00BMD6C023  G0174Z105  BMD6C02       <NA>            <NA>
# 758   181974050  GB00BVDPPV41  G7546B104  BVDPPV4       <NA>            <NA>
# 1274  260444328  GB00BYQCS703  G8353R109  BYQCS70       <NA>            <NA>
# 2716  269548375  US5006881065       <NA>  BJ1MZF7  500688106            <NA>
# 1516  483334121  GB00BD0SN947  G7112U106  BD0SN94       <NA>            <NA>
# 849   307717532  JE00BFZ1D698  G72090106  BFZ1D69       <NA>            <NA>
# 1209    1079451  BMG702782084  G70278208  BNYNCZ4       <NA>            <NA>
# 842   233143146  GB00BRBJ3P08  G4711X110  BRBJ3P0       <NA>            <NA>
# 945     1080637  GB00B1P6ZR11  G64036125  B1P6ZR1       <NA>            <NA>
# 290     1080192  GB0001500809  G91235104  0150080       <NA>            <NA>
# 151     1081314  GB00BK7YQK64  G4273Q164  BK7YQK6       <NA>            <NA>
# 384   157786753  GB00BLY2F708  G1895H101  BLY2F70       <NA>            <NA>
# 1321  314002711  GB00BD5JRP64  G471AD106  BD5JRP6       <NA>            <NA>
# 1790   16693373  BE0974264930  B0148L138  B83F4Z0       <NA>      110.593025
# 146     1281424  GB0031215220  G19081101  3121522       <NA>            <NA>
# 415     5440783  GB0030927254  G0536Q108  3092725       <NA>            <NA>
# 353     1049459  GB00B23K0M20  G1846J115  B23K0M2       <NA>            <NA>
# 634     1080901  GB0008025412  G80797106  0802541       <NA>            <NA>
# 694   151454135  GB00BMX64W89  G7770H124  BMX64W8       <NA>            <NA>
# 676    23694123  GB00BF0YPG76  G28933102  BF0YPG7       <NA>            <NA>
# 522   310249698  GB00BFFK8T45  G04043108  BFFK8T4       <NA>            <NA>
# 916     1081414  GB00B572ZV91  M7S90R102  B572ZV9       <NA>            <NA>
# 1199    1080165  GB00B9Z1M820  G12806116  B9Z1M82       <NA>            <NA>
# 136     1080671  GB00B1722W11  G5112P101  B1722W1       <NA>            <NA>
# 74      1331911  GB00B7KR2P84  G3030S109  B7KR2P8       <NA>            <NA>
# 75      1081572  GB0001859296  G9424B107  0185929       <NA>            <NA>
# 1120  561539980  GB00BNYDGM91  G303AL103  BNYDGM9       <NA>            <NA>
# 564    20125647  GB00BDGS8G04  G67783103  BDGS8G0       <NA>            <NA>
# 33     80673385  ES0177542018  E67674106  B5M6XQ7       <NA>            <NA>
# 592    32914850  GB00B18S7B29  G0127Z103  B18S7B2       <NA>            <NA>
# 613     1049411  GB00B1L5QH97  G7377H121  B1L5QH9       <NA>            <NA>
# 383     1081826  GB0002418548  G2996U108  0241854       <NA>            <NA>
# 191   212459602  GB00BD6GN030  G9413V106  BD6GN03       <NA>            <NA>
# 1330  309639361  GB00BDFGGK53  G8738Y100  BDFGGK5       <NA>            <NA>
# 988    18893038  GB00B040L800  G8406D107  B040L80       <NA>            <NA>
# 296   460400658  GB00BMTV7393  G8823P105  BMTV739       <NA>            <NA>
# 1076  154441880  JE00BH6XDL31  G9828U107  BH6XDL3       <NA>            <NA>
# 984    28667567  GB00B1FMDQ43  G389AW108  B1FMDQ4       <NA>            <NA>
# 272   126526970  GB00B8VZXT93  G25425102  B8VZXT9       <NA>            <NA>
# 2679  329864567  US38500T2006       <NA>  BR0WPZ4  38500T200            <NA>
# 1167   25240262  GB00B44W9L31  G52837120  B44W9L3       <NA>            <NA>
#
# [47 rows x 45 columns]

# %% [markdown]
# #### Get the Equities by Share Holders Equity

# %%
equities = lse_equities.query("ShareholdersEquityUsd >= 30_000_000_000")
plot_and_display(equities, "ShareholdersEquityUsd")
# Out:
# <div>                            <div id="751d7b68-e504-4c79-b93d-3c3e8212dbdc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("751d7b68-e504-4c79-b93d-3c3e8212dbdc")) {                    Plotly.newPlot(                        "751d7b68-e504-4c79-b93d-3c3e8212dbdc",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"ShareholdersEquityUsd","text":"","x":["Berkshire Hathaway Inc","Berkshire Hathaway Inc","Berkshire Hathaway Inc","Berkshire Hathaway Inc","JPMorgan Chase & Co","JPMorgan Chase & Co","Microsoft Corp","Microsoft Corp","Bank of America Corp","Bank of America Corp","Toyota Motor Corp","Toyota Motor Corp","Exxon Mobil Corp","Exxon Mobil Corp","Amazon.com Inc","Amazon.com Inc","Volkswagen AG","Volkswagen AG","China Mobile Ltd","Citigroup Inc","Citigroup Inc","Shell PLC","Shell PLC","HSBC Holdings PLC","HSBC Holdings PLC","Wells Fargo & Co","Wells Fargo & Co","Chevron Corp","Chevron Corp","Meta Platforms Inc","Meta Platforms Inc","Alibaba Group Holding Ltd","BNP Paribas SA","BNP Paribas SA","Mitsubishi UFJ Financial Group Inc","Postal Savings Bank of China Co Ltd","TotalEnergies SE","Tencent Holdings Ltd","Tencent Holdings Ltd","Banco Santander SA","Goldman Sachs Group Inc","Goldman Sachs Group Inc","Intel Corp","Intel Corp","AT&T Inc","AT&T Inc","Mercedes-Benz Group AG","Mercedes-Benz Group AG","Bayerische Motoren Werke AG","Bayerische Motoren Werke AG","Walt Disney Co","Walt Disney Co","Barclays PLC","Barclays PLC","Verizon Communications Inc","Verizon Communications Inc","Stellantis NV","Stellantis NV","Morgan Stanley","Pfizer Inc","Pfizer Inc","Unitedhealth Group Inc","Unitedhealth Group Inc","Honda Motor Co Ltd","UBS Group AG","UBS Group AG","Walmart Inc","Walmart Inc","Comcast Corp","Comcast Corp","Sanofi SA","Sanofi SA","Anheuser-Busch Inbev SA","Anheuser-Busch Inbev SA","Deutsche Bank AG","Deutsche Bank AG","Royal Bank of Canada","Royal Bank of Canada","Credit Agricole SA","Credit Agricole SA","SoftBank Group Corp","SoftBank Group Corp","CVS Health Corp","CVS Health Corp","Toronto-Dominion Bank","Toronto-Dominion Bank","Schweizerische Nationalbank","Schweizerische Nationalbank","Societe Generale SA","Societe Generale SA","UniCredit SpA","UniCredit SpA","Intesa Sanpaolo SpA","Intesa Sanpaolo SpA","BP PLC","BP PLC","BP PLC","Investor AB","Investor AB","Investor AB","British American Tobacco plc","British American Tobacco plc","Johnson & Johnson","Johnson & Johnson","Nippon Telegraph and Telephone Corp","LVMH Moet Hennessy Louis Vuitton SE","LVMH Moet Hennessy Louis Vuitton SE","Petroleo Brasileiro SA Petrobras","China Life Insurance Co Ltd","Vodafone Group PLC","Vodafone Group PLC","Allianz SE","Allianz SE","T-Mobile US Inc","T-Mobile US Inc","General Motors Co","Deutsche Telekom AG","Tesla Inc","Tesla Inc","Mitsubishi Corp","Mitsubishi Corp","Apple Inc","Apple Inc","Lloyds Banking Group PLC","Lloyds Banking Group PLC","RTX Corp","RTX Corp","Salesforce Inc","Salesforce Inc","Chubb Ltd","Chubb Ltd","Eni SpA","Eni SpA","Banco Bilbao Vizcaya Argentaria SA","ING Groep NV","ING Groep NV","Advanced Micro Devices Inc","Advanced Micro Devices Inc","AXA SA","Rio Tinto PLC","Rio Tinto Ltd","Rio Tinto PLC","AP Moeller - Maersk A\u002fS","AP Moeller - Maersk A\u002fS","ArcelorMittal SA","Bank of Montreal","Bank of Montreal","Danaher Corp","Danaher Corp","Capital One Financial Corp","Prologis Inc","Prologis Inc","Siemens AG","Siemens AG","PNC Financial Services Group Inc","Bank of Nova Scotia","Bank of Nova Scotia","Medtronic PLC","Medtronic PLC","Takeda Pharmaceutical Co Ltd","Takeda Pharmaceutical Co Ltd","Kraft Heinz Co","Procter & Gamble Co","Conocophillips","Conocophillips","NatWest Group PLC","US Bancorp","Equinor ASA","Equinor ASA","Standard Chartered PLC","Standard Chartered PLC","SAP SE","SAP SE","Iberdrola SA","Nextera Energy Inc","Nextera Energy Inc","Duke Energy Corp","Thermo Fisher Scientific Inc","Novartis AG","Novartis AG","ANZ G ...
#                 DTSubjectName           ExchangeName         RIC  \
# 1705   Berkshire Hathaway Inc  London Stock Exchange      0R37.L
# 1714   Berkshire Hathaway Inc  London Stock Exchange      0HN0.L
# 2898   Berkshire Hathaway Inc  London Stock Exchange  BRYNde.TRE
# 3483   Berkshire Hathaway Inc  London Stock Exchange   BRHde.TRE
# 3006      JPMorgan Chase & Co  London Stock Exchange    CMCf.TRE
# ...                       ...                    ...         ...
# 1820        Kinder Morgan Inc  London Stock Exchange      0JR2.L
# 2968  Manulife Financial Corp  London Stock Exchange      0V5H.L
# 3198  Manulife Financial Corp  London Stock Exchange    MLUf.TRE
# 1724              MetLife Inc  London Stock Exchange      0K0X.L
# 8029              MetLife Inc  London Stock Exchange    MWZf.TRE
#
#       MktCapCompanyUsd  ShareholdersEquityUsd         Pe  DebtToAssets  \
# 1705     1030190104605           561273000000  10.887372      0.466559
# 1714     1030190104605           561273000000  13.650934      0.466559
# 2898     1030190104605           561273000000       <NA>      0.466559
# 3483     1030190104605           561273000000       <NA>      0.466559
# 3006      624029979572           300474000000       <NA>      0.915395
# ...                ...                    ...        ...           ...
# 1820       47518694587            30306000000       <NA>      0.553239
# 2968       49136695264            30087368576       <NA>      0.944349
# 3198       49136695264            30087368576       <NA>      0.944349
# 1724       54289181984            30015000000  10.219681      0.956001
# 8029       54289181984            30015000000       <NA>      0.956001
#
#           Beta          Eps  \
# 1705  0.826016        43.95
# 1714  0.976085  47167.13691
# 2898      <NA>        43.95
# 3483      <NA>  47167.13691
# 3006      <NA>     17.93968
# ...        ...          ...
# 1820      <NA>      1.09475
# 2968      <NA>      2.35707
# 3198      <NA>      2.35707
# 1724      <NA>      3.71244
# 8029      <NA>      3.71244
#
#                                                    Gics  ...  \
# 1705  Financials/Financial Services/Financial Servic...  ...
# 1714  Financials/Financial Services/Financial Servic...  ...
# 2898  Financials/Financial Services/Financial Servic...  ...
# 3483  Financials/Financial Services/Financial Servic...  ...
# 3006           Financials/Banks/Banks/Diversified Banks  ...
# ...                                                 ...  ...
# 1820  Energy/Energy/Oil, Gas & Consumable Fuels/Oil ...  ...
# 2968  Financials/Insurance/Insurance/Life & Health I...  ...
# 3198  Financials/Insurance/Insurance/Life & Health I...  ...
# 1724  Financials/Insurance/Insurance/Life & Health I...  ...
# 8029  Financials/Insurance/Insurance/Life & Health I...  ...
#
#       RCSAssetCategory  RCSCurrencyLeaf  AssetState  BusinessEntity  \
# 1705              A:1L        US Dollar          AC    QUOTExEQUITY
# 1714              A:1L        US Dollar          AC    QUOTExEQUITY
# 2898              A:1L        US Dollar          AC    QUOTExEQUITY
# 3483              A:1L        US Dollar          AC    QUOTExEQUITY
# 3006              A:1L        US Dollar          AC    QUOTExEQUITY
# ...                ...              ...         ...             ...
# 1820              A:1L        US Dollar          AC    QUOTExEQUITY
# 2968              A:1L  Canadian Dollar          AC    QUOTExEQUITY
# 3198              A:1L  Canadian Dollar          AC    QUOTExEQUITY
# 1724              A:1L        US Dollar          AC    QUOTExEQUITY
# 8029              A:1L        US Dollar          AC    QUOTExEQUITY
#
#              PI     IssueISIN  CinCUSIP    SEDOL      CUSIP  SolvencyMargin
# 1705  286489815  US0846707026      <NA>  BSJC6M6  084670702            <NA>
# 1714  288061676  US0846701086      <NA>  BG05R83  084670108            <NA>
# 2898  286567046  US0846707026      <NA>     <NA>  084670702            <NA>
# 3483  288073919  US0846701086      <NA>     <NA>  084670108            <NA>
# 3006  291220094  US46625H1005      <NA>     <NA>  46625H100            <NA>
# ...         ...           ...       ...      ...        ...             ...
# 1820  287071019  US49456B1017      <NA>  BYZH7N5  49456B101            <NA>
# 2968  288201943  CA56501R1064      <NA>  BD6T9Z9  56501R106      134.155456
# 3198  288199067  CA56501R1064      <NA>     <NA>  56501R106      134.155456
# 1724  287071133  US59156R1086      <NA>  BYZH8V0  59156R108       63.979149
# 8029  287071773  US59156R1086      <NA>     <NA>  59156R108       63.979149
#
# [286 rows x 45 columns]

# %% [markdown]
# #### Get Equities by PE

# %%
equities = lse_equities.query("Pe >= 70")
plot_and_display(equities, "Pe")
# Out:
# <div>                            <div id="61efeb48-5737-4494-a19d-99ab50368b1a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("61efeb48-5737-4494-a19d-99ab50368b1a")) {                    Plotly.newPlot(                        "61efeb48-5737-4494-a19d-99ab50368b1a",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"Pe","text":"","x":["IQGeo Group PLC","Corero Network Security PLC","Attica Holdings SA","MercadoLibre Inc","Elica SpA","Power Metal Resources PLC","Essentra PLC","Tubacex SA","Equinix Inc","Dillistone Group PLC","Jupiter Green Investment Trust PLC","Airtel Africa PLC","ZUE SA","Net Insight AB","Riber SA","J Smart & Co (Contractors) PLC","Vow ASA","EPE Special Opportunities Ltd","Calnex Solutions PLC","Xvivo Perfusion AB","Worsley Investors Ltd","Baillie Gifford UK Growth Trust PLC","Supermarket Income REIT PLC","Comp SA","Beeks Financial Cloud Group PLC","GameStop Corp","Inapa Investimentos Participacoes e Gestao SA","Octopus Apollo VCT PLC","Signaux Girod SA","North Atlantic Smaller Companies Investment Trust PLC","Finsbury Growth & Income Trust PLC","Financiere Moncey SA","Octava SA","Jardine Matheson Holdings Ltd","Arrow Exploration Corp","Torm PLC","Virgin Wines UK PLC","Analog Devices Inc","Zumtobel Group AG","Aquila Energy Efficiency Trust PLC","High Co SA","Micropole SA","Aquila Energy Efficiency Trust PLC","Topps Tiles PLC","SSP Group PLC","Welltower Inc","EOG Resources Inc","DSW Capital PLC","Marks Electrical Group PLC","Vertex Pharmaceuticals Inc","Trustpilot Group PLC","Solar A\u002fS","EMC Instytut Medyczny SA","LBG Media PLC","Npl Nova SA","Greenyard NV","SBA Communications Corp","Soc Indust Financiere Artois SA","11 Bit Studios SA","Libertas 7 SA","Ramsay Generale de Sante SA","Rafako SA","AT & S Austria Technologie & Systemtechnik AG","Gas Plus SpA","N Brown Group PLC","Artmarket.com SA","UDR Inc","Animalcare Group plc","Halliburton Co","Franchise Brands PLC","Value8 NV","Centrum Medyczne Enel Med SA","Syncona Ltd","BF SpA","Crealogix Holding AG","CPD SA","Ryvu Therapeutics SA","Charter Communications Inc","Etablissements Maurel et Prom SA","Elektrotim SA","ActiveOps PLC","Mikron Holding AG","Atari SA","Keywords Studios PLC","SL Green Realty Corp","American International Group Inc","Begbies Traynor Group PLC","Tripadvisor Inc","Arendals Fossekompani ASA","Aurea SA","Rejlers AB (publ)","Bristol-Myers Squibb Co","Restore PLC","DFI Retail Group Holdings Ltd","DFI Retail Group Holdings Ltd","Craneware PLC","Altur SA","Hellenic Exchanges Athens Stock Exchange SA","Digital Realty Trust Inc","JZ Capital Partners Ltd","BioArctic AB","Cadence Design Systems Inc","Ibstock PLC","Crown Castle Inc","Capital & Regional PLC","Spirent Communications plc","Microlise Group PLC","Fiera Milano SpA","Cbrain A\u002fS","Pininfarina SpA","I Grandi Viaggi SpA","Becton Dickinson and Co","ID Logistics SAS","Axway Software SA","Intel Corp","Wallenius Wilhelmsen ASA","Perrigo Company PLC","HICL Infrastructure PLC","Mersen SA","Williams Companies Inc","Canada Goose Holdings Inc","Henderson Opportunities Trust PLC","Carlsberg A\u002fS","Maven Income and Growth VCT 3 PLC","ALBA SE","STM Group PLC","Mips AB","Munters Group AB","London Stock Exchange Group PLC","Schroder Real Estate Investment Trust Ltd","Southern Co","Sandstorm Gold Ltd","Sealed Air Corporation","Ra International Group Plc","Newriver Reit PLC","Krynica Vitamin SA","Firstfarms A\u002fS","Judges Scientific PLC","Alexandria Real Estate Equities Inc","Uber Technologies Inc","Synopsys Inc","Unieuro SpA","Josef Manner & Comp AG","JTC PLC","Geox SpA","Termo Rex SA","Bodegas Riojanas SA","Belysse Group NV","Grenevia SA","Qorvo Inc","Shaftesbury Capital PLC","Regency Centers Corp","Capital Gearing Trust PLC","CPI SA","ECO Animal Health Group PLC","Deliveroo PLC","Fincantieri SpA"],"y":[11162.790698,1750.2375,1646.464646,1186.971062,826.642336,825.0,771.296296,750.0,657.177115,633.333333,609 ...
#                     DTSubjectName           ExchangeName     RIC  \
# 319               IQGeo Group PLC  London Stock Exchange   IQG.L
# 1081  Corero Network Security PLC  London Stock Exchange  CNSP.L
# 4384           Attica Holdings SA  London Stock Exchange  0IKL.L
# 2181             MercadoLibre Inc  London Stock Exchange  0K0E.L
# 2607                    Elica SpA  London Stock Exchange  0EA2.L
# ...                           ...                    ...     ...
# 241     Capital Gearing Trust PLC  London Stock Exchange   CGT.L
# 4196                       CPI SA  London Stock Exchange  0OKA.L
# 794   ECO Animal Health Group PLC  London Stock Exchange   EAH.L
# 158                 Deliveroo PLC  London Stock Exchange   ROO.L
# 1762              Fincantieri SpA  London Stock Exchange  0QWN.L
#
#       MktCapCompanyUsd  ShareholdersEquityUsd            Pe  DebtToAssets  \
# 319          390000856               29921705  11162.790698       0.54573
# 1081         129568484               16737000     1750.2375      0.411415
# 4384         657517923              549297061   1646.464646      0.602075
# 2181      100968510546             3071000000   1186.971062      0.825966
# 2607         124910301              156136514    826.642336      0.635921
# ...                ...                    ...           ...           ...
# 241         1271922823             1393279356     72.605695      0.009124
# 4196           7260897                3400123     72.571429      0.736764
# 794           99713973              109985398     72.491909      0.242445
# 158         3081451947              668664960     71.918489      0.502153
# 1762        1675580137              479983584     70.636215      0.950154
#
#           Beta       Eps                                               Gics  \
# 319   0.543716   0.00043  Information Technology/Software & Services/Sof...
# 1081  1.046248   0.00014  Information Technology/Software & Services/Sof...
# 4384      <NA>   0.27875  Industrials/Transportation/Marine Transportati...
# 2181      <NA>  27.61621  Consumer Discretionary/Consumer Discretionary ...
# 2607      <NA>   0.03981  Consumer Discretionary/Consumer Durables & App...
# ...        ...       ...                                                ...
# 241   0.352136   0.65353                                               <NA>
# 4196      <NA>  -0.04929  Information Technology/Technology Hardware & E...
# 794   0.417754   0.01545  Health Care/Pharmaceuticals, Biotechnology & L...
# 158  -0.015184   0.02012  Consumer Discretionary/Consumer Services/Hotel...
# 1762      <NA> -0.292988  Industrials/Capital Goods/Machinery/Constructi...
#
#       ...  RCSAssetCategory  RCSCurrencyLeaf  AssetState  BusinessEntity  \
# 319   ...              A:1L    British Penny          AC    QUOTExEQUITY
# 1081  ...              A:1L    British Penny          AC    QUOTExEQUITY
# 4384  ...              A:1L             Euro          AC    QUOTExEQUITY
# 2181  ...              A:1L        US Dollar          AC    QUOTExEQUITY
# 2607  ...              A:1L             Euro          AC    QUOTExEQUITY
# ...   ...               ...              ...         ...             ...
# 241   ...              A:1L    British Penny          AC    QUOTExEQUITY
# 4196  ...              A:1L             Euro          AC    QUOTExEQUITY
# 794   ...              A:1L    British Penny          AC    QUOTExEQUITY
# 158   ...              A:1L    British Penny          AC    QUOTExEQUITY
# 1762  ...              A:1L             Euro          AC    QUOTExEQUITY
#
#              PI     IssueISIN   CinCUSIP    SEDOL      CUSIP  SolvencyMargin
# 319    88407885  GB00B3NCXX73  G4939N100  B3NCXX7       <NA>            <NA>
# 1081    1081298  GB00B54X0432  G252AK112  B54X043       <NA>            <NA>
# 4384  281898667  GRS144003001  X0265K109  B28F6W4       <NA>            <NA>
# 2181  286489892  US58733R1023       <NA>  BDDXSP7  58733R102            <NA>
# 2607  281899903  IT0003404214  T36140100  B28GYT0       <NA>            <NA>
# ...         ...           ...        ...      ...        ...             ...
# 241     1080650  GB0001738615  G1857A102  0173861       <NA>            <NA>
# 4196  281900366  GRS413313008  X1755D100  B28GLZ5       <NA>            <NA>
# 794     1079823  GB0032036807  G3039F108  3203680       <NA>            <NA>
# 158   500157044  GB00BNC5T391  G27035107  BNC5T39       <NA>            <NA>
# 1762  281905295  IT0005599938  T4R92H129  BT19SG0       <NA>            <NA>
#
# [157 rows x 45 columns]

# %% [markdown]
# #### Get Equities by Debt Ratio

# %%
equities = lse_equities.query("DebtToAssets >= 2")
plot_and_display(equities, "DebtToAssets")
# Out:
# <div>                            <div id="ef7a41a1-5330-4dd4-ac01-7dd9be871c6e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("ef7a41a1-5330-4dd4-ac01-7dd9be871c6e")) {                    Plotly.newPlot(                        "ef7a41a1-5330-4dd4-ac01-7dd9be871c6e",                        [{"line":{"color":"rgba(255, 153, 51, 1.0)","dash":"solid","shape":"linear","width":1.3},"mode":"lines","name":"DebtToAssets","text":"","x":["Smurfit WestRock PLC","Smurfit WestRock PLC","Cumulex NV","Lavide Holding NV","Carpinienne de Participations SA","Carpinienne de Participations SA","Dukemount Capital PLC","Selcodis SA","Oracle Energy Corp","Iconic Labs PLC","PBG SA w restrukturyzacji w likwidacji","PBG SA w restrukturyzacji w likwidacji","Curzon Energy PLC","Zinc One Resources Inc","Highway Capital PLC","CVR Medical Corp","CVR Medical Corp","Financiere Marjos SA","Katoro Gold PLC","Katoro Gold PLC","P2 Gold Inc","BluGo SA","BetterLife Pharma Inc","Catenai PLC","Fandango Holdings PLC","Plaza Centers NV","Plaza Centers NV","Rezolve AI Ltd","Cykel AI PLC","Adiuvo Investments SA","Ross Group PLC","Grand Vision Media Holdings PLC","Echo Energy PLC","Georgina Energy PLC","Georgina Energy PLC","Aurania Resources Ltd","Identillect Technologies Corp","Granada Gold Mine Inc","Resverlogix Corp","Resverlogix Corp","Power Group Projects Corp","Bedford Metals Corp","Adalan Ventures PLC","Baltic Bridge SA","Hopium SA","Sealand Capital Galaxy Ltd","Mobile Tornado Group PLC","Mobile Tornado Group PLC","ShiftPixy Inc","EPH SpA","EPH SpA","Shefa Gems Ltd","Shefa Gems Ltd","Neo Energy Metals PLC","Seelos Therapeutics Inc","OpGen Inc","Less SA","Fast Finance SA","Vistal Gdynia SA","Vistal Gdynia SA","Fortune Minerals Ltd","Fintech Asia Ltd","Innovative Solutions Ecosystem SA","Innovative Solutions Ecosystem SA","Fragrant Prosperity Holdings Ltd","Fragrant Prosperity Holdings Ltd","Europejskie Centrum Odszkodowan SA","Biotricity Inc","Orege SA","Atlantic Petroleum P\u002fF","Proton Motor Power Systems PLC","Lisgrafica Impressao e Artes Graficas SA","Lisgrafica Impressao e Artes Graficas SA","Boston International Holdings PLC","Boston International Holdings PLC","Remark Holdings Inc","Remark Holdings Inc","Arch Therapeutics Inc","Strax AB","Satis Group SA","FS Holding AD","Circio Holding ASA","Gensight Biologics SA","Biora Therapeutics Inc","Ebet Inc","EC Bedzin SA","Digitalist Group Oyj","Digitalist Group Oyj","Awakn Life Sciences Corp","CI Com SA","CI Com SA","Kinarus Therapeutics Holding AG","AIQ Ltd","Trafalgar Property Group PLC","Trafalgar Property Group PLC","Abacus Mining and Exploration Corp","GRIT Investment Trust PLC","BridgeBio Pharma Inc","Domino's Pizza Inc","Biosenic SA","Everest Global PLC","Ondo InsurTech PLC","CFI-Compagnie Fonciere Internationale SCA","CFI-Compagnie Fonciere Internationale SCA","Esperion Therapeutics Inc","Amala Foods PLC","Galectin Therapeutics Inc","Sporttotal AG","Winmark Corp","Krakchemia SA","Oxurion NV","Bulgarska Zahar AD","Idorsia Ltd","Navidea Biopharmaceuticals Inc","Airway Medix SA","Supply@Me Capital PLC","Ensurge Micropower ASA","Northwest Biotherapeutics Inc","Sato Office and Houseware Supplies SA","Sato Office and Houseware Supplies SA","Ves SA","Faron Pharmaceuticals Oy","Bioter SA","Acorda Therapeutics Inc","R8 Capital Investments PLC","i-nexus Global PLC","Reinhold Europe AB","Alpha MOS SA","Yum! Brands Inc","Eguana Technologies Inc","Eguana Technologies Inc","Newron Pharmaceuticals SpA","Newron Pharmaceuticals SpA","Pace Metals Ltd","Medincell SA","Medincell SA","Alkemy Capital Investments PLC","Alkemy Capital Investments PLC","Roadside Real Estate PLC","Roadside Real Estate PLC"],"y":[70770473.418182,70770473.418182,11405.857143,326.0,282.76,282.76,110.661234,100.841772,79.595545,73.450239,71.232,71.232,60.623881,55.565964,52.450062,46.648909,46.648909,43.278756,40.086957,40.086957,31.129153,29.694348,24.697521,24.439394,23.25,23.156475,23.156475,22.401663,21.678712,21.262919,19.545685,19.466424,16.15 ...
#                          DTSubjectName           ExchangeName           RIC  \
# 5380              Smurfit WestRock PLC  London Stock Exchange      SWRl.TRE
# 1682              Smurfit WestRock PLC  London Stock Exchange         SWR.L
# 4287                        Cumulex NV  London Stock Exchange        0G5T.L
# 4487                 Lavide Holding NV  London Stock Exchange        0QFQ.L
# 4957  Carpinienne de Participations SA  London Stock Exchange        0O1E.L
# ...                                ...                    ...           ...
# 9565                      Medincell SA  London Stock Exchange  MEDCLpa1.TRE
# 1082    Alkemy Capital Investments PLC  London Stock Exchange      ALKALK.L
# 7151    Alkemy Capital Investments PLC  London Stock Exchange      ALKl.TRE
# 7543          Roadside Real Estate PLC  London Stock Exchange     ROADl.TRE
# 2321          Roadside Real Estate PLC  London Stock Exchange        ROAD.L
#
#       MktCapCompanyUsd  ShareholdersEquityUsd         Pe     DebtToAssets  \
# 5380       23694557194                    110       <NA>  70770473.418182
# 1682       23694557194                    110  13.759781  70770473.418182
# 4287            658270               -2654161       <NA>     11405.857143
# 4487           1535263                -360165       <NA>            326.0
# 4957           2227910              -23418482  29.224192           282.76
# ...                ...                    ...        ...              ...
# 9565         593443529              -45241156       <NA>         2.104904
# 1082           5213014                -684238       <NA>         2.065051
# 7151           5213014                -684238       <NA>         2.065051
# 7543          39180434              -22588469       <NA>         2.056535
# 2321          39180434              -22588469  66.753927         2.056535
#
#           Beta       Eps                                               Gics  \
# 5380      <NA>   2.93302  Materials/Materials/Containers & Packaging/Pap...
# 1682    0.9067   2.93302  Materials/Materials/Containers & Packaging/Pap...
# 4287      <NA>  -0.17251                                               <NA>
# 4487      <NA>  -0.03843  Information Technology/Software & Services/IT ...
# 4957      <NA>  -3.86075  Real Estate/Real Estate Management & Developme...
# ...        ...       ...                                                ...
# 9565      <NA>  -0.87536  Health Care/Pharmaceuticals, Biotechnology & L...
# 1082   4.10827   -0.2249  Industrials/Capital Goods/Electrical Equipment...
# 7151      <NA>   -0.2249  Industrials/Capital Goods/Electrical Equipment...
# 7543      <NA>  0.003056  Consumer Discretionary/Consumer Services/Hotel...
# 2321  2.790108  0.003056  Consumer Discretionary/Consumer Services/Hotel...
#
#       ...  RCSAssetCategory  RCSCurrencyLeaf  AssetState  BusinessEntity  \
# 5380  ...              A:1L    British Penny          AC    QUOTExEQUITY
# 1682  ...              A:1L    British Penny          AC    QUOTExEQUITY
# 4287  ...              A:1L             Euro          AC    QUOTExEQUITY
# 4487  ...              A:1L             Euro          AC    QUOTExEQUITY
# 4957  ...              A:1L             Euro          AC    QUOTExEQUITY
# ...   ...               ...              ...         ...             ...
# 9565  ...              A:1L             Euro          AC    QUOTExEQUITY
# 1082  ...              A:1L    British Penny          AC    QUOTExEQUITY
# 7151  ...              A:1L    British Penny          AC    QUOTExEQUITY
# 7543  ...              A:1L    British Penny          AC    QUOTExEQUITY
# 2321  ...              A:1L    British Penny          AC    QUOTExEQUITY
#
#              PI     IssueISIN   CinCUSIP    SEDOL  CUSIP  SolvencyMargin
# 5380  279347930  IE00028FXN24  G8267P108     <NA>   <NA>            <NA>
# 1682   31968205  IE00028FXN24  G8267P108  BSMR1R8   <NA>            <NA>
# 4287  281905517  BE0003463685  B87945109  B28MPS4   <NA>            <NA>
# 4487  281899150  NL0010545679  N4R24V275  BCCVP98   <NA>            <NA>
# 4957  281902070  FR0000064156  F47355114  B28FNV2   <NA>            <NA>
# ...         ...           ...        ...      ...    ...             ...
# 9565  699844272  FR0004065605  F6104D107     <NA>   <NA>            <NA>
# 1082  549361066  GB00BMD6C023  G0174Z105  BMD6C02   <NA>            <NA>
# 7151  549361114  GB00BMD6C023  G0174Z105     <NA>   <NA>            <NA>
# 7543  408187847  GB00BL6TZZ70  G9453L109     <NA>   <NA>            <NA>
# 2321  408187845  GB00BL6TZZ70  G9453L109  BL6TZZ7   <NA>            <NA>
#
# [140 rows x 45 columns]

# %% [markdown]
# ### Get Vodafone related equities and use get_data() to retrieve additional information

# %%
vod_equities = equity.search(what="vodafone", exchange_name="London Stock Exchange")

ld.get_data(
    universe=vod_equities['RIC'].to_list(),
    fields=['TR.RevenueSmartEst.date', 'TR.RevenueSmartEst', 'TR.NetprofitSmartEst', 'TR.EpsSmartEst']
)
# Out:
#          Instrument       Date  Revenue - SmartEstimate®  \
# 0             VOD.L 2024-09-03               37296622960
# 1          VODl.TRE 2024-09-03               37296622960
# 2            0QBL.L        NaT                      <NA>
# 3        0QBLic.TRE        NaT                      <NA>
# 4  AU0000090128.TRE 2024-09-05                5566799830
#
#    Net Income - SmartEstimate®  Earnings Per Share - SmartEstimate®
# 0                   2176576400                              0.08228
# 1                   2176576400                              0.08228
# 2                         <NA>                                 <NA>
# 3                         <NA>                                 <NA>
# 4                    241730990                              0.12634

# %% [markdown]
# ## Close the session

# %%
ld.close_session()
