# %% [markdown]
# ----
# <img src="../../files/lseg.svg" class="rft-examples-logo" width="20%" style="vertical-align: top;">
#
# # Data Library for Python
#
# ----

# %% [markdown]
# ## Content layer - Search
# This notebook demonstrates how to use the Search service of the LSEG Data Platform.

# %% [markdown]
# #### Learn more
#
# To learn more about the LSEG Data Library for Python please join the LSEG Developer Community. By [registering](https://developers.lseg.com/iam/register) and [logging](https://developers.lseg.com/content/devportal/en_us/initCookie.html) into the LSEG Developer Community portal you will have free access to a number of learning materials like
#  [Quick Start guides](https://developers.lseg.com/en/api-catalog/lseg-data-platform/lseg-data-library-for-python/quick-start),
#  [Tutorials](https://developers.lseg.com/en/api-catalog/lseg-data-platform/lseg-data-library-for-python/tutorials),
#  [Documentation](https://developers.lseg.com/en/api-catalog/lseg-data-platform/lseg-data-library-for-python/documentation)
#  and much more.
#
# #### Getting Help and Support
#
# If you have any questions regarding using the API, please post them on
# the [Data Library Q&A Forum](https://community.developers.refinitiv.com/smart-spaces/521/index.html).
# The LSEG Developer Community will be happy to help.
#
# ----

# %% [markdown]
# ## Some Imports to start with

# %%
import lseg.data as ld
from lseg.data.content import search

# %% [markdown]
# ## Open the data session
#
# The open_session() function creates and open sessions based on the information contained in the lseg-data.config.json configuration file. Please edit this file to set the session type and other parameters required for the session you want to open.

# %%
ld.open_session()
# Out:
# <lseg.data.session.Definition object at 0x13882fac0 {name='workspace'}>

# %% [markdown]
# ## Retrieve data

# %% [markdown]
# ### General Search

# %%
response = search.Definition("IBM Bonds").get_data()
response.data.df
# Out:
#                    BusinessEntity  \
# 0  INSTRUMENTxFIXEDINCOMExGOVCORP
# 1  INSTRUMENTxFIXEDINCOMExGOVCORP
# 2  INSTRUMENTxFIXEDINCOMExGOVCORP
# 3  INSTRUMENTxFIXEDINCOMExGOVCORP
# 4  INSTRUMENTxFIXEDINCOMExGOVCORP
# 5  INSTRUMENTxFIXEDINCOMExGOVCORP
# 6  INSTRUMENTxFIXEDINCOMExGOVCORP
# 7  INSTRUMENTxFIXEDINCOMExGOVCORP
# 8  INSTRUMENTxFIXEDINCOMExGOVCORP
# 9  INSTRUMENTxFIXEDINCOMExGOVCORP
#
#                                        DocumentTitle        PermID  \
# 0  International Business Machines Corp, Plain Va...  192826895881
# 1  International Business Machines Corp, Plain Va...   46644611190
# 2  Fideicomiso Fibra Uno, Plain Vanilla Fixed Cou...   44658934367
# 3  International Business Machines Corp, Plain Va...  232796002153
# 4  Fideicomiso Fibra Uno, Fixed Margin over Index...  232779066893
# 5  International Business Machines Corp, Plain Va...   15628361579
# 6  International Business Machines Corp, Plain Va...   44652137828
# 7  Fideicomiso Fibra Uno, Plain Vanilla Fixed Cou...   46637470062
# 8  Fideicomiso Fibra Uno, Plain Vanilla Fixed Cou...   46637469894
# 9  Ibm International Capital Pte Ltd, Plain Vanil...  232836247320
#
#                    PI            RIC
# 0  0x00102c8de61f1850   US194445610=
# 1  0x00102c00c0900d61   US161784508=
# 2  0x0004051cd9531a8d        FUNO15=
# 3  0x00102cfffd953398     459200KS9=
# 4  0x00102cb061232de3  FUNO212X=VALR
# 5  0x0000fa00068e7c0e     459200AM3=
# 6  0x00040514f83234eb   US099109963=
# 7  0x00102ca4794f05ab   MX133173986=
# 8  0x00102cb77c4f05bd     898324AC2=
# 9  0x001055f1ed370b65     449276AA2=

# %% [markdown]
# ### Specify number of rows to fetch

# %%
response = search.Definition("IBM Bonds", top=100).get_data()
response.data.df
# Out:
#                     BusinessEntity  \
# 0   INSTRUMENTxFIXEDINCOMExGOVCORP
# 1   INSTRUMENTxFIXEDINCOMExGOVCORP
# 2   INSTRUMENTxFIXEDINCOMExGOVCORP
# 3   INSTRUMENTxFIXEDINCOMExGOVCORP
# 4   INSTRUMENTxFIXEDINCOMExGOVCORP
# ..                             ...
# 95  INSTRUMENTxFIXEDINCOMExGOVCORP
# 96  INSTRUMENTxFIXEDINCOMExGOVCORP
# 97  INSTRUMENTxFIXEDINCOMExGOVCORP
# 98  INSTRUMENTxFIXEDINCOMExGOVCORP
# 99  INSTRUMENTxFIXEDINCOMExGOVCORP
#
#                                         DocumentTitle        PermID  \
# 0   International Business Machines Corp, Plain Va...  192826895881
# 1   International Business Machines Corp, Plain Va...   46644611190
# 2   Fideicomiso Fibra Uno, Plain Vanilla Fixed Cou...   44658934367
# 3   International Business Machines Corp, Plain Va...  232796002153
# 4   Fideicomiso Fibra Uno, Fixed Margin over Index...  232779066893
# ..                                                ...           ...
# 95  IBM Credit LLC, Plain Vanilla Fixed Coupon Bon...   15628870427
# 96  IBM Credit LLC, Plain Vanilla Fixed Coupon Bon...   15628377011
# 97  IBM Credit LLC, Plain Vanilla Fixed Coupon Bon...   15629030262
# 98  IBM Credit LLC, Plain Vanilla Fixed Coupon Bon...   15629030258
# 99  IBM Credit LLC, Plain Vanilla Fixed Coupon Bon...   15629030225
#
#                     PI            RIC
# 0   0x00102c8de61f1850   US194445610=
# 1   0x00102c00c0900d61   US161784508=
# 2   0x0004051cd9531a8d        FUNO15=
# 3   0x00102cfffd953398     459200KS9=
# 4   0x00102cb061232de3  FUNO212X=VALR
# ..                 ...            ...
# 95  0x000386001f82352d           <NA>
# 96  0x0000fa000a004bbb           <NA>
# 97  0x000386003ff16f24           <NA>
# 98  0x000386003ff16b20           <NA>
# 99  0x000386003ff1470c           <NA>
#
# [100 rows x 5 columns]

# %% [markdown]
# ### Filter Expressions

# %%
response = search.Definition(
    view=search.Views.GOV_CORP_INSTRUMENTS,
    select="ISIN,RIC,IssueDate,Currency,FaceIssuedTotal,CouponRate,MaturityDate", 
    filter="IssuerTicker eq 'IBM' and IsActive eq true and AssetStatus ne 'MAT'"
).get_data()
response.data.df
# Out:
#            ISIN           RIC  IssueDate Currency  FaceIssuedTotal  \
# 0  XS1944456109  US194445610= 2019-01-31      EUR       1000000000
# 1  XS1617845083  US161784508= 2017-05-23      EUR       1000000000
# 2  US459200KS93    459200KS9= 2022-07-27      USD       1000000000
# 3  US459200AM34    459200AM3= 1995-10-30      USD        600000000
# 4  XS0991099630  US099109963= 2013-11-07      EUR       1000000000
# 5  US459200KW06    459200KW0= 2023-02-06      USD        850000000
# 6  US459200JG74    459200JG7= 2016-02-19      USD       1350000000
# 7  US459200JZ55    459200JZ5= 2019-05-15      USD       3000000000
# 8  XS1512978112  US151297811= 2016-11-02      JPY      42000000000
# 9  US459200JR30    459200JR3= 2017-01-27      USD        500000000
#
#    CouponRate MaturityDate
# 0       0.875   2025-01-31
# 1        0.95   2025-05-23
# 2         4.0   2025-07-27
# 3         7.0   2025-10-30
# 4       2.875   2025-11-07
# 5         4.5   2026-02-06
# 6        3.45   2026-02-19
# 7         3.3   2026-05-15
# 8         0.3   2026-11-02
# 9         3.3   2027-01-27

# %% [markdown]
# ### Properties - Metadata

# %%
response = search.metadata.Definition(
    view = search.Views.GOV_CORP_INSTRUMENTS
).get_data() 

response.data.df
# Out:
#                                                         Type  Searchable  \
# AccrualDate               AccrualDate                   Date        True
# AccruedInterest           AccruedInterest             Double        True
# ActiveEstimatesExist      ActiveEstimatesExist       Boolean        True
# AdtLocalCurrencyValue     AdtLocalCurrencyValue       String        True
# AdtLocalCurrencyValueName AdtLocalCurrencyValueName   String        True
# ...                                                      ...         ...
# WorstStandardYield        WorstStandardYield          Double        True
# WorstYearsToRedem         WorstYearsToRedem           Double        True
# YieldCurveBenchmarkRIC    YieldCurveBenchmarkRIC      String       False
# YieldTypeDescription      YieldTypeDescription        String        True
# ZCodeValue                ZCodeValue                  String        True
#
#                                                      Sortable  Navigable  \
# AccrualDate               AccrualDate                    True       True
# AccruedInterest           AccruedInterest                True       True
# ActiveEstimatesExist      ActiveEstimatesExist          False      False
# AdtLocalCurrencyValue     AdtLocalCurrencyValue         False      False
# AdtLocalCurrencyValueName AdtLocalCurrencyValueName     False      False
# ...                                                       ...        ...
# WorstStandardYield        WorstStandardYield             True       True
# WorstYearsToRedem         WorstYearsToRedem              True       True
# YieldCurveBenchmarkRIC    YieldCurveBenchmarkRIC        False      False
# YieldTypeDescription      YieldTypeDescription          False      False
# ZCodeValue                ZCodeValue                     True      False
#
#                                                      Groupable  Exact  Symbol
# AccrualDate               AccrualDate                    False  False   False
# AccruedInterest           AccruedInterest                False  False   False
# ActiveEstimatesExist      ActiveEstimatesExist           False  False   False
# AdtLocalCurrencyValue     AdtLocalCurrencyValue          False  False   False
# AdtLocalCurrencyValueName AdtLocalCurrencyValueName      False  False   False
# ...                                                        ...    ...     ...
# WorstStandardYield        WorstStandardYield             False  False   False
# WorstYearsToRedem         WorstYearsToRedem              False  False   False
# YieldCurveBenchmarkRIC    YieldCurveBenchmarkRIC         False  False   False
# YieldTypeDescription      YieldTypeDescription           False  False   False
# ZCodeValue                ZCodeValue                      True  False    True
#
# [1189 rows x 7 columns]

# %% [markdown]
# ### Navigators

# %%
response = search.Definition(
    top=0,
    navigators="RCSTRBC2012Leaf"
).get_data()

response.data.raw
# Out:
# {'Total': 155388167,
#  'Hits': [],
#  'Navigators': {'RCSTRBC2012Leaf': {'Buckets': [{'Label': 'Banks (NEC)',
#      'Count': 5806180},
#     {'Label': 'Corporate Financial Services (NEC)', 'Count': 3217209},
#     {'Label': 'Corporate Banks', 'Count': 1683542},
#     {'Label': 'Retail & Mortgage Banks', 'Count': 1576821},
#     {'Label': 'Investment Banking & Brokerage Services (NEC)',
#      'Count': 1041604},
#     {'Label': 'Construction & Engineering (NEC)', 'Count': 770400},
#     {'Label': 'Government & Government Finance (NEC)', 'Count': 769936},
#     {'Label': 'Business Support Services (NEC)', 'Count': 713315},
#     {'Label': 'Public Finance Activities', 'Count': 585407},
#     {'Label': 'Investment Holding Companies (NEC)', 'Count': 545590},
#     {'Label': 'Investment Banking', 'Count': 498542},
#     {'Label': 'Real Estate Rental, Development & Operations (NEC)',
#      'Count': 486806},
#     {'Label': 'Electric Utilities (NEC)', 'Count': 466723},
#     {'Label': 'Consumer Lending (NEC)', 'Count': 433730},
#     {'Label': 'Wealth Management', 'Count': 429437},
#     {'Label': 'Supermarkets & Convenience Stores', 'Count': 372354},
#     {'Label': 'Diversified Investment Services', 'Count': 353092},
#     {'Label': 'IT Services & Consulting (NEC)', 'Count': 347548},
#     {'Label': 'Building Contractors', 'Count': 327110},
#     {'Label': 'Real Estate Services (NEC)', 'Count': 308865},
#     {'Label': 'Investment Management & Fund Operators (NEC)', 'Count': 298055},
#     {'Label': 'Software (NEC)', 'Count': 293358},
#     {'Label': 'Shell Companies', 'Count': 292002},
#     {'Label': 'Professional Information Services (NEC)', 'Count': 272435},
#     {'Label': 'Department Stores (NEC)', 'Count': 238381},
#     {'Label': 'Management Consulting Services', 'Count': 224477},
#     {'Label': 'Auto Vehicles, Parts & Service Retailers (NEC)',
#      'Count': 203985},
#     {'Label': 'Healthcare Facilities & Services (NEC)', 'Count': 184113},
#     {'Label': 'Personal Services (NEC)', 'Count': 183609},
#     {'Label': 'Hospitals, Clinics & Primary Care Services', 'Count': 176835},
#     {'Label': 'Homebuilding (NEC)', 'Count': 176499},
#     {'Label': 'Miscellaneous Educational Service Providers', 'Count': 164320},
#     {'Label': 'Residential Real Estate Rental & Development', 'Count': 163234},
#     {'Label': 'Investment Management', 'Count': 152600},
#     {'Label': 'Restaurants & Bars (NEC)', 'Count': 150667},
#     {'Label': 'Pharmaceuticals (NEC)', 'Count': 149285},
#     {'Label': 'Metal Merchant Wholesale', 'Count': 147501},
#     {'Label': 'Integrated Telecommunications Services (NEC)', 'Count': 145657},
#     {'Label': 'Residential Builders - Single Homes', 'Count': 137506},
#     {'Label': 'Diversified Industrial Goods Wholesale', 'Count': 131291},
#     {'Label': 'Food Processing (NEC)', 'Count': 122201},
#     {'Label': 'Brokerage Services', 'Count': 119928},
#     {'Label': 'Government Administration Activities', 'Count': 119461},
#     {'Label': 'Commodity Chemicals (NEC)', 'Count': 117449},
#     {'Label': 'Leisure & Recreation (NEC)', 'Count': 117070},
#     {'Label': 'Industrial Machinery & Equipment (NEC)', 'Count': 111500},
#     {'Label': 'Oil & Gas Exploration and Production (NEC)', 'Count': 111049},
#     {'Label': 'Auto, Truck & Motorcycle Parts (NEC)', 'Count': 104449},
#     {'Label': 'E-commerce & Auction Services', 'Count': 104105},
#     {'Label': 'Commercial Loans', 'Count': 100983},
#     {'Label': 'Construction Materials (NEC)', 'Count': 97635},
#     {'Label': 'Insurance Brokers', 'Count': 94039},
#     {'Label': 'Highway & Bridge Construction', 'Count': 92478},
#     {'Label': 'Metallic Rolling & Drawing Products', 'Count': 91246},
#     {'Label': 'Financial & Commodity Market Operators & Service Providers (NEC)',
#      'Count': 89955},
#     {'Label': 'Food Retail & Distribution (NEC)', 'Count': 89343},
#     {'Label': 'Closed End Funds', 'Count': 88412},
#     {'Label': 'Ground Freight & Logistics (NEC)', 'Count': 87106},
#     {'Label': 'Biotechnology & Medical Research (NEC)', 'Count': 86032},
#     {'Label': 'Multiline Utilities', 'Count': 84871},
#     {'Label': 'UK Investment Trusts', 'Count': 83549},
#     {'Label': 'Online Services (NEC)', 'Count': 83390},
#     {'Label': 'Office Real Estate Rental & Development', 'Count': 82713},
#     {'Label': 'Electrical Components & Equipment (NEC)', 'Count': 80106},
#     {'Label': 'Maintenance & Repair Services', 'Count': 78795},
#     {'Label': 'Passenger Transportation, Ground & Sea (NEC)', 'Count': 78323},
#     {'Label': 'Food Wholesale', 'Count': 77365},
#     {'Label': 'Gasoline Stations', 'Count': 77326},
#     {'Label': 'Hotels & Motels', 'Count': 74802},
#     {'Label': 'Freight Trucking', 'Count': 73551},
#     {'Label': 'Industrial Machinery', 'Count': 72697},
#     {'Label': 'Plastics', 'Count': 72172},
#     {'Label': 'Advertising & Marketing (NEC)', 'Count': 71751},
#     {'Label': 'Civil Engineers & Architects', 'Count': 71394},
#     {'Label': 'Employment Services (NEC)', 'Count': 70695},
#     {'Label': 'Life & Health Insurance (NEC)', 'Count': 67688},
#     {'Label': "Doctor's Office", 'Count': 67327},
#     {'Label': 'Fishing & Farming Wholesale', 'Count': 67235},
#     {'Label': 'Metal Service Centers', 'Count': 66998},
#     {'Label': 'Legal Services', 'Count': 66794},
#     {'Label': 'Entertainment Production (NEC)', 'Count': 66189},
#     {'Label': 'Iron & Steel (NEC)', 'Count': 65759},
#     {'Label': 'Commercial Buildings', 'Count': 65256},
#     {'Label': 'Waste Management, Disposal & Recycling Services',
#      'Count': 64937},
#     {'Label': 'Miscellaneous Specialty Retailers (NEC)', 'Count': 64037},
#     {'Label': 'Natural Gas Distribution', 'Count': 62199},
#     {'Label': 'Personal Products (NEC)', 'Count': 61751},
#     {'Label': 'Drug Retailers (NEC)', 'Count': 59229},
#     {'Label': 'Oil & Gas Refining and Marketing (NEC)', 'Count': 58908},
#     {'Label': 'Consumer Goods Conglomerates', 'Count': 58307},
#     {'Label': 'Iron, Steel Mills & Foundries', 'Count': 57898},
#     {'Label': 'Personal Care Services', 'Count': 57360},
#     {'Label': 'Diversified Mining', 'Count': 57029},
#     {'Label': 'Advertising Agency', 'Count': 56152},
#     {'Label': 'Integrated Oil & Gas', 'Count': 55791},
#     {'Label': 'Child Care & Family Services', 'Count': 55642},
#     {'Label': 'Industrial Machinery & Equipment Wholesale', 'Count': 54731},
#     {'Label': 'Food Markets', 'Count': 53900},
#     {'Label': 'Hedge Funds', 'Count': 53795},
#     {'Label': 'Industrial Equipment Rental', 'Count': 53457}]}}}

# %% [markdown]
# ### Search with Navigator option

# %%
response = search.Definition(
    view=search.Views.COMMODITY_QUOTES,
    query="cheese",
    navigators="ExchangeName"
).get_data()

response.data.df
# Out:
#     BusinessEntity                                      DocumentTitle  \
# 0  QUOTExCOMMODITY  CME Cash Settled Cheese Electronic Commodity F...
# 1  QUOTExCOMMODITY  CME Cash Settled Cheese Electronic Commodity F...
# 2  QUOTExCOMMODITY  CME Cash Settled Cheese Electronic Commodity F...
# 3  QUOTExCOMMODITY  CME Cash Settled Cheese Electronic Commodity F...
# 4  QUOTExCOMMODITY  CME Cash Settled Cheese Electronic Commodity F...
# 5  QUOTExCOMMODITY  CME Cash Settled Cheese Electronic Commodity F...
# 6  QUOTExCOMMODITY  CME Cash Settled Cheese Electronic Commodity F...
# 7  QUOTExCOMMODITY  CME Cash Settled Cheese Electronic Commodity F...
# 8  QUOTExCOMMODITY  CME Cash Settled Cheese Electronic Commodity F...
# 9  QUOTExCOMMODITY  CME Cash Settled Cheese Electronic Commodity F...
#
#         PermID         PI     RIC
# 0  21622940491  273610776   CSCc1
# 1  21622425217  272623267  0#CSC:
# 2  21915186698  635366864  CSCQ24
# 3  21928467711  651474399  CSCV24
# 4  21622940494  273610782   CSCc2
# 5  21922779318  644632832  CSCU24
# 6  21622940497  273610784   CSCc3
# 7  21934325409  658555795  CSCX24
# 8  21941309049  666775593  CSCZ24
# 9  21622940500  273610787   CSCc4

# %%
response.data.raw["Navigators"]['ExchangeName']
# Out:
# {'Buckets': [{'Label': 'CME:Index and Options Market', 'Count': 18068},
#   {'Label': 'Source is a Refinitiv Contributor', 'Count': 4472},
#   {'Label': 'Chicago Mercantile Exchange', 'Count': 3087},
#   {'Label': 'INTL FCStone Inc', 'Count': 2550},
#   {'Label': 'US Department of Agriculture', 'Count': 103},
#   {'Label': 'Commodity Futures Trading Commission', 'Count': 66},
#   {'Label': 'Complete Intelligence', 'Count': 65},
#   {'Label': 'Intercontinental Exchange US', 'Count': 31},
#   {'Label': 'US Bureau Of Labor Statistics', 'Count': 10},
#   {'Label': 'DCA Markets B.V. - DCA-Markets-PRA Price Reporting Agent',
#    'Count': 4},
#   {'Label': 'European Commission', 'Count': 3},
#   {'Label': 'ESALQ', 'Count': 2},
#   {'Label': 'Refinitiv', 'Count': 2},
#   {'Label': 'CME:International Monetary Market', 'Count': 1}]}

# %%
response = search.Definition(
    view=search.Views.GOV_CORP_INSTRUMENTS,
    top=0,
    navigators="Currency(buckets:10,desc:sum_FaceOutstandingUSD,calc:max_CouponRate)"
).get_data()

response.data.raw
# Out:
# {'Total': 12180634,
#  'Hits': [],
#  'Navigators': {'Currency': {'Buckets': [{'Label': 'USD',
#      'Count': 4622961,
#      'max_CouponRate': 1800.0,
#      'sum_FaceOutstandingUSD': 56232704160706.0},
#     {'Label': 'EUR',
#      'Count': 1274572,
#      'max_CouponRate': 999.999999,
#      'sum_FaceOutstandingUSD': 27885937274377.0},
#     {'Label': 'CNY',
#      'Count': 452856,
#      'max_CouponRate': 72.0,
#      'sum_FaceOutstandingUSD': 23409487317229.0},
#     {'Label': 'JPY',
#      'Count': 526718,
#      'max_CouponRate': 999.999999,
#      'sum_FaceOutstandingUSD': 10798779334248.125},
#     {'Label': 'GBP',
#      'Count': 245490,
#      'max_CouponRate': 999.999999,
#      'sum_FaceOutstandingUSD': 5310514063817.0},
#     {'Label': 'INR',
#      'Count': 135928,
#      'max_CouponRate': 42.75,
#      'sum_FaceOutstandingUSD': 2926057720109.0},
#     {'Label': 'CAD',
#      'Count': 373871,
#      'max_CouponRate': 100.0,
#      'sum_FaceOutstandingUSD': 2733717592341.0},
#     {'Label': 'KRW',
#      'Count': 450212,
#      'max_CouponRate': 48.0,
#      'sum_FaceOutstandingUSD': 2412527929576.0107},
#     {'Label': 'AUD',
#      'Count': 193492,
#      'max_CouponRate': 999.999999,
#      'sum_FaceOutstandingUSD': 1756062955035.0},
#     {'Label': 'BRL',
#      'Count': 105959,
#      'max_CouponRate': 999.999999,
#      'sum_FaceOutstandingUSD': 1023371335818.2799}]}}}

# %% [markdown]
# #### Sub-navigator

# %%
response = search.Definition(
    view=search.Views.PEOPLE,
    top=0,
    navigators="FirstName(buckets:3,sub:LastName(buckets:2))"
).get_data()

response.data.raw["Navigators"]["FirstName"]["Buckets"]
# Out:
# [{'Label': 'John',
#   'Count': 45455,
#   'LastName': {'Buckets': [{'Label': 'Smith', 'Count': 123},
#     {'Label': 'Wilson', 'Count': 120}]}},
#  {'Label': 'David',
#   'Count': 45365,
#   'LastName': {'Buckets': [{'Label': 'Smith', 'Count': 261},
#     {'Label': 'Brown', 'Count': 186}]}},
#  {'Label': 'Michael',
#   'Count': 43774,
#   'LastName': {'Buckets': [{'Label': 'Smith', 'Count': 207},
#     {'Label': 'Brown', 'Count': 149}]}}]

# %% [markdown]
# ### Search with order_by option

# %%
response = search.Definition(
    view=search.Views.PEOPLE,
    query="ceo",
    order_by="YearOfBirth desc,LastName,FirstName",
    select="YearOfBirth,DocumentTitle"
).get_data()

response.data.df
# Out:
#    YearOfBirth                                      DocumentTitle
# 0         1997  Carl Fredrik Mikael Akerman - VOLTA GREENTECH ...
# 1         1997  Martins Balodis - Facing It International - Ch...
# 2         1997  David Samuel Haloho - David Sistem Group PT - ...
# 3         1997  Dhiraj Kochar - Vdeal System Ltd - Managing Di...
# 4         1997  Ulviyya Rustamova - Level Zero Health Inc - Ch...
# 5         1997  Rishi Tandon - Creative Casuals (India) Pvt Lt...
# 6         1997  Paul-Louis Venard - Phospho SAS - Chief Execut...
# 7         1996  Senthil Nathan Abishiek - Acsen Tex Pvt Ltd - ...
# 8         1996  Mitchell Babalola Christopher Fasanya - Search...
# 9         1996  Ethan Fraenkel - Prograd uk Inc - Chief Execut...

# %% [markdown]
# ### Search with group_by option

# %%
response = search.Definition(
    view=search.Views.INDICATOR_QUOTES,
    query="rate",
    group_by="CentralBankName",
    group_count=2,
    select="CentralBankName,DocumentTitle,RIC"
).get_data()

response.data.df
# Out:
#           CentralBankName                                      DocumentTitle  \
# 0  Federal Reserve System  United States, Policy Rates, Fed Funds Target ...
# 1  Federal Reserve System  United States, Policy Rates, Fed Overnight Rep...
# 2       Sveriges Riksbank  Sweden, Policy Rates, Riksbank Rate (Effective...
# 3       Sveriges Riksbank  Sweden, Riksbank Rate-Sest, Reuters Polls, Dai...
# 4          Bank Indonesia  Indonesia, Policy Rates, 7-Day Reverse Repo, R...
# 5          Bank Indonesia  Indonesia, Policy Rates, Deposit Facility Rate...
# 6        Bank of Thailand  Thailand, Policy Rates, 1-Day Repurchase Rate ...
# 7        Bank of Thailand  Thailand, 1-Day Repo Rate -Sest, Reuters Polls...
# 8           Bank of Korea  South Korea, Policy Rates, Base Rate, Reuters ...
# 9           Bank of Korea  South Korea, BASE RATE - YUANTA SEC, Reuters P...
#
#                   RIC
# 0          USFOMC=ECI
# 1           USRRP=ECI
# 2          SERATE=ECI
# 3           pSERATE=F
# 4          IDCBRR=ECI
# 5          IDCBID=ECI
# 6          THCBIR=ECI
# 7           pTHCBIR=F
# 8          KROCRT=ECI
# 9  pKROCRT=5000012417

# %% [markdown]
# ### Search For People

# %%
response = search.Definition(
    query="cfo",
    view=search.Views.PEOPLE
).get_data()

response.data.df
# Out:
#   BusinessEntity                                      DocumentTitle  \
# 0         PERSON  Amy E. Hood - Microsoft Corp - Chief Financial...
# 1         PERSON  Luca Maestri - Apple Inc - Chief Financial Off...
# 2         PERSON  Brian T. Olsavsky - Amazon.com Inc - Senior Vi...
# 3         PERSON  Susan J. Li - Meta Platforms Inc - Chief Finan...
# 4         PERSON  Marc D. Hamburg - Berkshire Hathaway Inc - Chi...
# 5         PERSON  Andrew K. Klatt - Berkshire Hathaway Inc - CFO...
# 6         PERSON  Xu Hong - Alibaba Group Holding Ltd - Chief Fi...
# 7         PERSON  John Lo - Tencent Holdings Ltd - Chief Financi...
# 8         PERSON  Jeremy Barnum - JPMorgan Chase & Co - Chief Fi...
# 9         PERSON  Francois-Xavier Roger - Nestle SA - Member of ...
#
#         PermID           PI
# 0  34415553383  34415553383
# 1  34414554748  34414554748
# 2  34417610894  34417610894
# 3  34424688603  34424688603
# 4  34413152672  34413152672
# 5  34414966250  34414966250
# 6  34425652371  34425652371
# 7  34414907131  34414907131
# 8  34425402851  34425402851
# 9  34421446607  34421446607

# %% [markdown]
# ## Close the session

# %%
ld.close_session()
