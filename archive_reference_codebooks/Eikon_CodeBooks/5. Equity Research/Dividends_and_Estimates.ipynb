# %% [markdown]
# ## Dividends and Estimates
# This notebook demonstrates how to use the get_data calls of the Access layer to show the basics of retrieving dividends and dividend estimates data both individual broker, IBES concensus and SmartEstimates - as well as broker recommendations and target prices.
#
# The Access layer provides a simplified programmatic interface designed for FinCoders.

# %% [markdown]
# #### Learn more
#
# To learn more about the Data Library for Python please join the LSEG Developer Community. By [registering](https://developers.lseg.com/iam/register) and [logging](https://developers.lseg.com/content/devportal/en_us/initCookie.html) into the LSEG Developer Community portal you will have free access to a number of learning materials like
#  [Quick Start guides](https://developers.lseg.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/quick-start),
#  [Tutorials](https://developers.lseg.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/learning),
#  [Documentation](https://developers.lseg.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/docs)
#  and much more.
#
# #### Getting Help and Support
#
# If you have any questions regarding using the API, please post them on
# this [Q&A Forum](https://community.developers.refinitiv.com/spaces/321/index.html).
# The LSEG Developer Community will be happy to help.
#
# ----

# %% [markdown]
# ## Some Imports to start with

# %%
import refinitiv.data as rd
import pandas as pd
import numpy as np

# %% [markdown]
# ## Open the data session
#
# The open_session() function creates and open sessions based on the information contained in the refinitiv-data.config.json configuration file. Please edit this file to set the session type and other parameters required for the session you want to open.

# %%
rd.open_session()
# Out:
# <refinitiv.data.session.Definition object at 0x127ec0b20 {name='workspace'}>

# %% [markdown]
# ## Retrieve data
#
# ### Get Dividend History for BHP.AX in USD

# %%
rd.get_data('BHP.AX',['TR.DivExDate','TR.DivRecordDate','TR.DivPayDate','TR.DivUnadjustedGross',
                      'TR.DivAdjustedGross','TR.DivCurr'],
            parameters={'SDate':'2000-01-01', 'EDate':'1D', 'Curn':'USD'})
# Out:
#    Instrument Dividend Ex Date Dividend Record Date Dividend Pay Date  \
# 0      BHP.AX       2000-06-05           2000-06-09        2000-07-03
# 1      BHP.AX       2000-11-13           2000-11-17        2000-12-06
# 2      BHP.AX       2001-06-04           2001-06-08        2001-07-02
# 3      BHP.AX       2001-11-12           2001-11-16        2001-12-05
# 4      BHP.AX       2002-06-03           2002-06-07        2002-07-03
# 5      BHP.AX       2002-11-11           2002-11-15        2002-12-04
# 6      BHP.AX       2003-06-06           2003-06-13        2003-07-02
# 7      BHP.AX       2003-11-10           2003-11-14        2003-12-03
# 8      BHP.AX       2004-04-08           2004-04-16        2004-05-05
# 9      BHP.AX       2004-08-30           2004-09-03        2004-09-22
# 10     BHP.AX       2005-02-28           2005-03-04        2005-03-23
# 11     BHP.AX       2005-09-05           2005-09-09        2005-09-28
# 12     BHP.AX       2006-02-27           2006-03-03        2006-03-22
# 13     BHP.AX       2006-09-04           2006-09-08        2006-09-27
# 14     BHP.AX       2007-02-26           2007-03-02        2007-03-20
# 15     BHP.AX       2007-09-10           2007-09-14        2007-09-28
# 16     BHP.AX       2008-02-25           2008-02-29        2008-03-18
# 17     BHP.AX       2008-09-01           2008-09-05        2008-09-25
# 18     BHP.AX       2009-02-23           2009-02-27        2009-03-17
# 19     BHP.AX       2009-08-31           2009-09-04        2009-09-25
# 20     BHP.AX       2010-03-01           2010-03-05        2010-03-23
# 21     BHP.AX       2010-09-06           2010-09-10        2010-09-30
# 22     BHP.AX       2011-03-07           2011-03-11        2011-03-31
# 23     BHP.AX       2011-09-05           2011-09-09        2011-09-29
# 24     BHP.AX       2012-02-27           2012-03-02        2012-03-22
# 25     BHP.AX       2012-09-03           2012-09-07        2012-09-28
# 26     BHP.AX       2013-03-04           2013-03-08        2013-03-28
# 27     BHP.AX       2013-09-02           2013-09-06        2013-09-25
# 28     BHP.AX       2014-03-03           2014-03-07        2014-03-26
# 29     BHP.AX       2014-09-03           2014-09-05        2014-09-23
# 30     BHP.AX       2015-03-11           2015-03-13        2015-03-31
# 31     BHP.AX       2015-09-09           2015-09-11        2015-09-29
# 32     BHP.AX       2016-03-10           2016-03-11        2016-03-31
# 33     BHP.AX       2016-09-01           2016-09-02        2016-09-20
# 34     BHP.AX       2017-03-09           2017-03-10        2017-03-28
# 35     BHP.AX       2017-09-07           2017-09-08        2017-09-26
# 36     BHP.AX       2018-03-08           2018-03-09        2018-03-27
# 37     BHP.AX       2018-09-06           2018-09-07        2018-09-25
# 38     BHP.AX       2019-03-07           2019-03-08        2019-03-26
# 39     BHP.AX       2019-01-10           2019-01-11        2019-01-30
# 40     BHP.AX       2019-09-05           2019-09-06        2019-09-25
# 41     BHP.AX       2020-03-05           2020-03-06        2020-03-24
# 42     BHP.AX       2020-09-03           2020-09-04        2020-09-22
# 43     BHP.AX       2021-03-04           2021-03-05        2021-03-23
# 44     BHP.AX       2021-09-02           2021-09-03        2021-09-21
# 45     BHP.AX       2022-02-24           2022-02-25        2022-03-28
# 46     BHP.AX       2022-05-25           2022-05-26        2022-06-01
# 47     BHP.AX       2022-09-01           2022-09-02        2022-09-22
# 48     BHP.AX       2023-03-09           2023-03-10        2023-03-30
# 49     BHP.AX       2023-09-07           2023-09-08        2023-09-28
#
#     Gross Dividend Amount  Adjusted Gross Dividend Amount Dividend Currency
# 0                0.153556                        0.067018               AUD
# 1                0.131475                         0.05951               AUD
# 2                0.192735                        0.087238               AUD
# 3                0.094154                        0.088016               AUD
# 4                0.092174                        0.086164               AUD
# 5                0.099231                        0.099231               AUD
# 6                0.108171                        0.108171               AUD
# 7                0.111851                        0.111851               AUD
# 8                0.121798                        0.121798               AUD
# 9                0.135298                        0.135298               AUD
# 10               0.192253                        0.192253               AUD
# 11               0.207208                        0.207208               AUD
# 12               0.250041                        0.250041               AUD
# 13                0.25686                         0.25686               AUD
# 14               0.286986                        0.286986               AUD
# 15               0.396256                        0.396256               AUD
# 16               0.408754                        0.408754               AUD
# 17               0.581922                        0.581922               AUD
# 18               0.596428                        0.596428               AUD
# 19               0.546802                        0.546802               AUD
# 20               0.577432                        0.577432               AUD
# 21               0.603323                        0.603323               AUD
# 22               0.627548                        0.627548               AUD
# 23               0.805333                        0.805333               AUD
# 24               0.732225                        0.732225               AUD
# 25                0.82491                         0.82491               AUD
# 26               0.829613                        0.829613               AUD
# 27               0.840237                        0.840237               AUD
# 28               0.866003                        0.866003               AUD
# 29               0.889816                        0.889816               AUD
# 30               1.014459                        1.014459               AUD
# 31               0.959699                        0.959699               AUD
# 32               0.213644                        0.213644               AUD
# 33               0.203573                        0.203573               AUD
# 34               0.579101                        0.579101               AUD
# 35               0.574876                        0.574876               AUD
# 36               0.794692                        0.794692               AUD
# 37                0.93858                         0.93858               AUD
# 38               0.792851                        0.792851               AUD
# 39               1.464364                        1.464364               AUD
# 40               1.104538                        1.104538               AUD
# 41               0.974721                        0.974721               AUD
# 42                0.78043                         0.78043               AUD
# 43               1.452978                        1.452978               AUD
# 44               2.859576                        2.859576               AUD
# 45               2.125434                        2.125434               AUD
# 46                   <NA>                            <NA>              <NA>
# 47               2.559851                        2.559851               AUD
# 48               1.345126                        1.345126               AUD
# 49               1.147204                        1.147204               AUD

# %% [markdown]
# ### Get Current Dividend for S&P500 Index

# %%
rd.get_data('0#.SPX',['TR.DivExDate','TR.DivRecordDate','TR.DivPayDate','TR.DivUnadjustedGross',
                      'TR.DivAdjustedGross','TR.DivCurr'],
            parameters={'EDate':'FQ0', 'Curn':'USD'})
# Out:
#     Instrument Dividend Ex Date Dividend Record Date Dividend Pay Date  \
# 0      POOL.OQ              NaT                  NaT               NaT
# 1      CHRW.OQ       2024-02-29           2024-03-01        2024-04-01
# 2        AJG.N       2024-02-29           2024-03-01        2024-03-15
# 3        CNP.N              NaT                  NaT               NaT
# 4       AMCR.N       2024-02-27           2024-02-28        2024-03-19
# ..         ...              ...                  ...               ...
# 505      PSX.N       2024-02-16           2024-02-20        2024-03-01
# 506     SCHW.N       2024-02-08           2024-02-09        2024-02-23
# 507    SNPS.OQ              NaT                  NaT               NaT
# 508        J.N       2024-02-22           2024-02-23        2024-03-22
# 509      AVY.N       2024-03-05           2024-03-06        2024-03-20
#
#      Gross Dividend Amount  Adjusted Gross Dividend Amount Dividend Currency
# 0                     <NA>                            <NA>
# 1                     0.61                            0.61               USD
# 2                      0.6                             0.6               USD
# 3                     <NA>                            <NA>
# 4                    0.125                           0.125               USD
# ..                     ...                             ...               ...
# 505                   1.05                            1.05               USD
# 506                   0.25                            0.25               USD
# 507                   <NA>                            <NA>
# 508                   0.29                            0.29               USD
# 509                   0.81                            0.81               USD
#
# [510 rows x 7 columns]

# %% [markdown]
# ### Get Dividend Broker Estimates FY1,FY2,FY3

# %%
rd.get_data('0#.SPX',['TR.DPSEstValue(Period=FY1).brokername','TR.DPSEstValue(Period=FY1).analystname','TR.DPSEstValue(Period=FY1)',
                      'TR.DPSMeanYield(Period=FY1)','TR.DPSEstValue(Period=FY2).brokername','TR.DPSEstValue(Period=FY2).analystname',
                      'TR.DPSEstValue(Period=FY2)','TR.DPSMeanYield(Period=FY2)','TR.DPSEstValue(Period=FY3).brokername',
                      'TR.DPSEstValue(Period=FY3).analystname','TR.DPSEstValue(Period=FY3)','TR.DPSMeanYield(Period=FY3)'],
            )
# Out:
#      Instrument              Broker Name              Analyst Name  \
# 0       POOL.OQ     BOFA GLOBAL RESEARCH             Calnan, Shaun
# 1       POOL.OQ            GOLDMAN SACHS          Maklari, Susan M
# 2       POOL.OQ  OPPENHEIMER & CO., INC.  Schneeberger, CFA, Scott
# 3       POOL.OQ            DEUTSCHE BANK          Ahlersmeyer, Joe
# 4       POOL.OQ  WILLIAM BLAIR & COMPANY            Merkel, Ryan J
# ...         ...                      ...                       ...
# 5642      AVY.N        MORNINGSTAR, INC.         Liberman, Spencer
# 5643      AVY.N         REDBURN ATLANTIC            Isaac, Colin A
# 5644      AVY.N             UBS EQUITIES           Spector, Joshua
# 5645      AVY.N            RAYMOND JAMES             Roberts, Matt
# 5646      AVY.N                     CITI        Pettinari, Anthony
#
#       Dividend Per Share - Broker Estimate Dividend Per Share Yield %  \
# 0                                      4.3                   1.097687
# 1                                      4.3
# 2                                      4.3
# 3                                      4.3
# 4                                      4.1
# ...                                    ...                        ...
# 5642                                  3.32
# 5643                                  3.35
# 5644                                  3.46
# 5645                                   3.0
# 5646                                   3.0
#
#                   Broker Name              Analyst Name  \
# 0        BOFA GLOBAL RESEARCH             Calnan, Shaun
# 1               GOLDMAN SACHS          Maklari, Susan M
# 2     OPPENHEIMER & CO., INC.  Schneeberger, CFA, Scott
# 3               DEUTSCHE BANK          Ahlersmeyer, Joe
# 4     WILLIAM BLAIR & COMPANY            Merkel, Ryan J
# ...                       ...                       ...
# 5642        MORNINGSTAR, INC.         Liberman, Spencer
# 5643         REDBURN ATLANTIC            Isaac, Colin A
# 5644             UBS EQUITIES           Spector, Joshua
# 5645            RAYMOND JAMES             Roberts, Matt
# 5646                     CITI        Pettinari, Anthony
#
#       Dividend Per Share - Broker Estimate Dividend Per Share Yield %  \
# 0                                     4.55                   1.193871
# 1                                      4.7
# 2                                      4.4
# 3                                     4.57
# 4                                      4.4
# ...                                    ...                        ...
# 5642                                  3.36
# 5643                                   3.7
# 5644                                  3.81
# 5645                                   3.0
# 5646                                   3.0
#
#                   Broker Name             Analyst Name  \
# 0               DEUTSCHE BANK         Ahlersmeyer, Joe
# 1               GOLDMAN SACHS         Maklari, Susan M
# 2     WILLIAM BLAIR & COMPANY           Merkel, Ryan J
# 3            LONGBOW RESEARCH  MacGregor, CFA, David S
# 4
# ...                       ...                      ...
# 5642        MORNINGSTAR, INC.        Liberman, Spencer
# 5643             UBS EQUITIES          Spector, Joshua
# 5644            RAYMOND JAMES            Roberts, Matt
# 5645                     CITI       Pettinari, Anthony
# 5646
#
#       Dividend Per Share - Broker Estimate Dividend Per Share Yield %
# 0                                     4.97                   1.311258
# 1                                      5.1
# 2                                     4.84
# 3                                      5.5
# 4                                     <NA>
# ...                                    ...                        ...
# 5642                                  3.68
# 5643                                  4.19
# 5644                                   3.0
# 5645                                   3.0
# 5646                                  <NA>
#
# [5647 rows x 13 columns]

# %% [markdown]
# ### Get Dividend Broker Estimates FQ1,FQ2,FQ3,FQ4

# %%
rd.get_data('0#.SPX',['TR.DPSEstValue(Period=FQ1).brokername','TR.DPSEstValue(Period=FQ1).analystname','TR.DPSEstValue(Period=FQ1)',
                      'TR.DPSMeanYield(Period=FQ1)','TR.DPSEstValue(Period=FQ2).brokername','TR.DPSEstValue(Period=FQ2).analystname',
                      'TR.DPSEstValue(Period=FQ2)','TR.DPSMeanYield(Period=FQ2)','TR.DPSEstValue(Period=FQ3).brokername',
                      'TR.DPSEstValue(Period=FQ3).analystname','TR.DPSEstValue(Period=FQ3)','TR.DPSMeanYield(Period=FQ3)'],
            )

# %% [markdown]
# ### Get IBES Consensus Dividend Estimates

# %%
rd.get_data('0#.SPX',['TR.DPSMean(Period=FY1)','TR.DPSSmartEst(Period=FY1)','TR.DPSSENumIncEst(Period=FY1)','TR.DPSMean(Period=FY2)',
                      'TR.DPSSmartEst(Period=FY2)','TR.DPSSENumIncEst(Period=FY2)','TR.DPSMean(Period=FY3)','TR.DPSSmartEst(Period=FY3)',
                      'TR.DPSSENumIncEst(Period=FY3)'],
            )
# Out:
#     Instrument  Dividend Per Share - Mean  \
# 0      POOL.OQ                    4.27143
# 1      CHRW.OQ                    2.47385
# 2        AJG.N                    2.37714
# 3        CNP.N                    0.76683
# 4       AMCR.N                    0.50063
# ..         ...                        ...
# 498      PSX.N                     4.3305
# 499     SCHW.N                       1.08
# 500    SNPS.OQ                        0.0
# 501        J.N                     1.1595
# 502      AVY.N                    3.26714
#
#      Dividend Per Share - SmartEstimate®  \
# 0                                 4.2708
# 1                                2.52048
# 2                                 2.3856
# 3                                0.76683
# 4                                0.49833
# ..                                   ...
# 498                              4.35877
# 499                              1.07887
# 500                                  0.0
# 501                              1.19426
# 502                              3.38381
#
#      Dividend Per Share - SmartEstimate Num of Included Estimates  \
# 0                                                    5
# 1                                                    6
# 2                                                    4
# 3                                                    9
# 4                                                    3
# ..                                                 ...
# 498                                                  8
# 499                                                  8
# 500                                                  1
# 501                                                  5
# 502                                                  4
#
#      Dividend Per Share - Mean  Dividend Per Share - SmartEstimate®  \
# 0                      4.64571                               4.4546
# 1                      2.59333                              2.61097
# 2                      2.53714                              2.55698
# 3                      0.82117                              0.82612
# 4                       0.5075                              0.50775
# ..                         ...                                  ...
# 498                    4.57609                               4.6184
# 499                    1.18909                              1.19418
# 500                        0.0                                  0.0
# 501                     1.2392                               1.3147
# 502                    3.41286                              3.48526
#
#      Dividend Per Share - SmartEstimate Num of Included Estimates  \
# 0                                                    5
# 1                                                    6
# 2                                                    5
# 3                                                   10
# 4                                                    7
# ..                                                 ...
# 498                                                  8
# 499                                                  8
# 500                                                  2
# 501                                                  7
# 502                                                  6
#
#      Dividend Per Share - Mean  Dividend Per Share - SmartEstimate®  \
# 0                       5.1025                              4.89247
# 1                      2.89167                              2.71591
# 2                       2.7025                              2.70138
# 3                      0.87982                              0.88878
# 4                      0.47857                              0.46027
# ..                         ...                                  ...
# 498                      4.786                              4.67049
# 499                    1.25388                              1.20762
# 500                        0.0                                 <NA>
# 501                    1.34667                              1.33819
# 502                       3.79                              3.78365
#
#      Dividend Per Share - SmartEstimate Num of Included Estimates
# 0                                                    2
# 1                                                    4
# 2                                                    4
# 3                                                   10
# 4                                                    6
# ..                                                 ...
# 498                                                  3
# 499                                                  6
# 500                                               <NA>
# 501                                                  3
# 502                                                  4
#
# [503 rows x 10 columns]

# %% [markdown]
# ### Get Broker Recommendations and Target Prices

# %%
rd.get_data('IBM.N',["TR.BrkRecLabel.date", "TR.BrkRecLabel.brokername", "TR.BrkRecLabel.analystname", 
            "TR.BrkRecLabel.analystcode", "TR.BrkRecLabel", "TR.TPEstValue"])
# Out:
#    Instrument       Date                                Broker Name  \
# 0       IBM.N 2016-11-10                       BOFA GLOBAL RESEARCH
# 1       IBM.N 2023-06-06                  CRISPIDEA PRIVATE LIMITED
# 2       IBM.N 2023-07-07                                   JPMORGAN
# 3       IBM.N 2023-12-13                                       HSBC
# 4       IBM.N 2014-02-25                        BMO CAPITAL MARKETS
# 5       IBM.N 2024-01-19                               EVERCORE ISI
# 6       IBM.N 2016-08-15                    OPPENHEIMER & CO., INC.
# 7       IBM.N 2020-07-22                 ARGUS RESEARCH CORPORATION
# 8       IBM.N 2024-01-05                           SOCIETE GENERALE
# 9       IBM.N 2011-03-15                                  BERNSTEIN
# 10      IBM.N 2017-08-03                    WEDBUSH SECURITIES INC.
# 11      IBM.N 2022-01-10                               UBS EQUITIES
# 12      IBM.N 2023-12-21                     CFRA RESEARCH/NOMURAWM
# 13      IBM.N 2023-07-17                            MELIUS RESEARCH
# 14      IBM.N 2010-07-13  STIFEL NICOLAUS AND COMPANY, INCORPORATED
# 15      IBM.N 2024-01-05                                  JEFFERIES
# 16      IBM.N 2017-10-18                                    DZ BANK
# 17      IBM.N 2017-04-19              DAIWA CAPITAL MARKETS AMERICA
# 18      IBM.N 2017-07-19                         CLEVELAND RESEARCH
# 19      IBM.N 2023-01-18                             MORGAN STANLEY
# 20      IBM.N 2024-01-29                                 EQUISIGHTS
# 21      IBM.N 2023-09-20                        RBC CAPITAL MARKETS
#
#                Analyst Name Analyst Code Broker Rec Descr. - Broker Estimate  \
# 0              Mohan, Wamsi         46DE                                 BUY
# 1           Sanwaria, Ankit         8Q2O                                HOLD
# 2              Essex, Brian         8N8T                             NEUTRAL
# 3         Bersey, Stephen D         8QLR                              REDUCE
# 4          Bachman, Keith F         42TM                      MARKET PERFORM
# 5         Daryanani, Amit J         7T0U                          OUTPERFORM
# 6             Kidron, Ittai         4754                             PERFORM
# 7           Kelleher, Jim N         1BV9                                 BUY
# 8           Nguyen, Richard         44OE                                SELL
# 9   Sacconaghi, A.M. (Toni)         8HQZ                       MARKETPERFORM
# 10             Katri, Moshe         7BI1                             NEUTRAL
# 11              Vogt, David         849D                                SELL
# 12            Idlet, Brooks         8SEA                                 BUY
# 13           Reitzes, Ben A         8R9K                                 BUY
# 14        Grossman, David M         4SSI                                 BUY
# 15           Thill, Brent J         7GM0                                HOLD
# 16            Wermann, Ingo         4J40                                 BUY
# 17          Tanaka, Satoshi         4111                                   3
# 18           Terjanian, Ari         7FJ9                             NEUTRAL
# 19         Woodring, Erik W         763K                     EQUALWT/IN-LINE
# 20          Talsania, Parth         8R03                                HOLD
# 21       Swanson, Matthew J         8476                          OUTPERFORM
#
#     Target Price - Broker Estimate
# 0                            190.0
# 1                            200.0
# 2                            146.0
# 3                            210.0
# 4                            172.0
# 5                            140.0
# 6                            165.0
# 7                            215.0
# 8                            165.0
# 9                            193.0
# 10                           224.0
# 11                           125.0
# 12                           190.0
# 13                           215.0
# 14                           196.0
# 15                           200.0
# 16                           186.0
# 17                           210.0
# 18                          182.63
# 19                            <NA>
# 20                            <NA>
# 21                            <NA>

# %% [markdown]
# ### Close the session

# %%
rd.close_session()
