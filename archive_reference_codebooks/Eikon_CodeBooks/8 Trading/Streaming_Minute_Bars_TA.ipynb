# %% [markdown]
# # Streaming 1 minute bars with technical analyis triggers

# %% [markdown]
# This notebook demonstrates how to build 1 minute bars with Data Libraries Streaming services and enrich them with technical analysis indicators/signals. The notebook introduces two options: one with price snapshot and another with stream recorder.

# %% [markdown]
# #### Learn more
#
# To learn more about the Data Library for Python please join the LSEG Developer Community. By [registering](https://developers.lseg.com/iam/register) and [logging](https://developers.lseg.com/content/devportal/en_us/initCookie.html) into the LSEG Developer Community portal you will have free access to a number of learning materials like
#  [Quick Start guides](https://developers.lseg.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/quick-start),
#  [Tutorials](https://developers.lseg.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/learning),
#  [Documentation](https://developers.lseg.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/docs)
#  and much more.
#
# #### Getting Help and Support
#
# If you have any questions regarding using the API, please post them on
# this [Q&A Forum](https://community.developers.refinitiv.com/spaces/321/index.html).
# The LSEG Developer Community will be happy to help.
#
# ----

# %% [markdown]
# Below we import the requited packages:

# %%
import refinitiv.data as rd
import pandas as pd
import numpy as np
import talib as ta
import time
import re
from datetime import datetime, timedelta

pd.options.mode.chained_assignment = None

rd.open_session()

# %% [markdown]
# ## Defining functions for producting TA signals

# %% [markdown]
# Below we define functions to calculate moving averages, rsi and stochastic signals.

# %%
# Define SMA function
def get_sma(close, short_period, long_period):
    short_sma = ta.SMA(close, short_period)[-2:]
    long_sma = ta.SMA(close,long_period)[-2:]
    sma_sell = ((short_sma <= long_sma) & (short_sma.shift(1) >= long_sma.shift(1)))
    sma_buy = ((short_sma >= long_sma) & (short_sma.shift(1) <= long_sma.shift(1)))
    return short_sma[-1], long_sma[-1], sma_sell[-1], sma_buy[-1]

# %%
#Define RSI function
def get_rsi(close, period):
    rsi = ta.RSI(close, period)[-2:]
    rsi_sell = (rsi>70) & (rsi.shift(1)<=70)
    rsi_buy = (rsi<30) & (rsi.shift(1)>=30)
    return rsi[-1], rsi_sell[-1], rsi_buy[-1]

# %%
#Define Stoch function
def get_stoch(close, high, low):
    slowk, slowd = ta.STOCH(high, low, close)
    stoch_sell = ((slowk < slowd) & (slowk.shift(1) > slowd.shift(1))) & (slowd > 80)
    stoch_buy = ((slowk > slowd) & (slowk.shift(1) < slowd.shift(1))) & (slowd < 20)
    return slowk[-1], slowd[-1], stoch_sell[-1], stoch_buy[-1]

# %% [markdown]
# ## Functions for running technical analyis streaming data

# %% [markdown]
# Here we provide two functions which enable building 1 minute streaming bars along with technical analysis triggers. The first function uses get_snapshot function from the Data Libraries and the other one stream.recorder function.

# %% [markdown]
# ### Function with gettting the snapshot

# %% [markdown]
# This function runs by combining the historical data with 1 minute pricing snapshots. We first request historical data in 1 minute interval for the requested assets, open a stream and get a snapshot of the stream every minute. By appending the latest snapshot with the historical datapoints we calculate ta indicators and produce triggers.

# %%
def run_ta_stream_snap(assets, asset_dict, assets_prices, stream, tech_indicators):
    new_assets_prices = {}
    price_snap = stream.get_snapshot()
    for asset in assets:
        prices_asset = assets_prices[asset]
        price_snap_asset = price_snap.loc[price_snap['Instrument'] == asset]
        date = price_snap_asset['CF_DATE'].values[0]
        time = price_snap_asset['CF_TIME'].values[0]
        print(f'Received price snapshot for {asset} as of {time}')
        
        price_snap_asset['CF_TIME'] = price_snap_asset['CF_TIME'].str[:5]
        prices = pd.concat([prices_asset, price_snap_asset.set_index('CF_TIME')])
        new_assets_prices[asset] = prices
        
        short_sma, long_sma, sma_sell, sma_buy = get_sma(prices['BID'],tech_indicators['s_ma'], tech_indicators['l_ma'])
        print(f' Short SMA: {short_sma} Long SMA: {long_sma} \n sma_sell: {sma_sell}, sma_buy: {sma_buy}')

        slowk, slowd, stoch_sell, stoch_buy  = get_stoch(prices['BID'], prices['BID_HIGH_1'], prices['BID_LOW_1'])
        print(f' SlowK: {slowk} SlowD: {slowd} \n stoch_sell: {stoch_sell}, stoch_buy: {stoch_buy}')

        rsi, rsi_sell,rsi_buy  = get_rsi(prices['BID'], tech_indicators['rsi_period'])   
        print(f' RSI: {rsi} \n rsi_sell: {rsi_sell}, rsi_buy: {rsi_buy}\n')
        
        asset_dict[asset].append({'Date':date, 'Time':time, 'short_sma':short_sma, 'long_sma':long_sma, 'sma_sell':sma_sell, 'sma_buy':sma_buy, 
                                  'rsi':rsi, 'rsi_sell':rsi_sell, 'rsi_buy':rsi_buy,  
                                  'slowK':slowk, 'slowD':slowd, 'stoch_sell':stoch_buy, 'stoch_buy':stoch_buy})
        
    assets_prices = pd.concat([df for df in new_assets_prices.values()], axis =1,
                              keys = [key for key in new_assets_prices.keys()])
    return assets_prices

# %%
def run_ta_stream_snap(assets, asset_dict, assets_prices, stream, tech_indicators):
    new_assets_prices = {}

    price_snap = stream.get_snapshot()
    for asset in assets:
        prices_asset = assets_prices[asset]
        price_snap_asset = price_snap.loc[price_snap['Instrument'] == asset]

        date = price_snap_asset.at[price_snap_asset.index[0], 'CF_DATE']
        time = price_snap_asset.at[price_snap_asset.index[0], 'CF_TIME']
        print(f'Received price snapshot for {asset} as of {time}')

        price_snap_asset.loc[:, 'CF_TIME'] = price_snap_asset['CF_TIME'].str[:5]
        prices = pd.concat([prices_asset, price_snap_asset.set_index('CF_TIME')])

        new_assets_prices[asset] = prices

        short_sma, long_sma, sma_sell, sma_buy = get_sma(prices['BID'], tech_indicators['s_ma'], tech_indicators['l_ma'])
        print(f'Short SMA: {short_sma} Long SMA: {long_sma} \nSMA sell: {sma_sell}, SMA buy: {sma_buy}')

        slowk, slowd, stoch_sell, stoch_buy = get_stoch(prices['BID'], prices['BID_HIGH_1'], prices['BID_LOW_1'])
        print(f'SlowK: {slowk} SlowD: {slowd} \nStoch sell: {stoch_sell}, Stoch buy: {stoch_buy}')

        rsi, rsi_sell, rsi_buy = get_rsi(prices['BID'], tech_indicators['rsi_period'])
        print(f'RSI: {rsi} \nRSI sell: {rsi_sell}, RSI buy: {rsi_buy}\n')

        asset_dict[asset].append({'Date': date, 'Time': time, 'short_sma': short_sma, 'long_sma': long_sma,
                                  'sma_sell': sma_sell, 'sma_buy': sma_buy, 'rsi': rsi, 'rsi_sell': rsi_sell,
                                  'rsi_buy': rsi_buy, 'slowK': slowk, 'slowD': slowd, 'stoch_sell': stoch_buy,
                                  'stoch_buy': stoch_buy})

    assets_prices = pd.concat([df for df in new_assets_prices.values()], axis=1, keys=assets)
    return assets_prices

# %% [markdown]
# Now, let's initialize the parameters

# %%
asset_dict = {'GBP=':[], 'EUR=':[], 'JPY=':[]}
assets = list(asset_dict.keys())
start = datetime.now() - timedelta(minutes = 20)
interval = '1min'
tech_indicators = {'s_ma':10, 'l_ma':20, 'rsi_period': 14}
timeout = time.time() + 300

# %%
assets_prices  = rd.get_history(assets, ['BID', 'BID_HIGH_1', 'BID_LOW_1'], start = start, 
                             interval = interval, count=max(tech_indicators['l_ma'], tech_indicators['rsi_period']) + 10).dropna()
stream = rd.open_pricing_stream(universe= assets,
                                fields=['CF_DATE', 'CF_TIME', 'BID', 'BID_HIGH_1', 'BID_LOW_1'])

while time.time() < timeout:
    time.sleep(60)
    assets_prices = run_ta_stream_snap(assets, asset_dict, assets_prices, stream, tech_indicators)
stream.close()
# Out:
# Received price snapshot for GBP= as of 10:46:32
# Short SMA: 1.2475799999999997 Long SMA: 1.2477649999999998
# SMA sell: False, SMA buy: False
# SlowK: 21.506734006734874 SlowD: 15.269360269360563
# Stoch sell: False, Stoch buy: True
# RSI: 38.69923390003167
# RSI sell: False, RSI buy: False
#
# Received price snapshot for EUR= as of 10:46:31
# Short SMA: 1.09282 Long SMA: 1.0927950000000002
# SMA sell: False, SMA buy: False
# SlowK: 28.636363636363683 SlowD: 12.878787878787895
# Stoch sell: False, Stoch buy: False
# RSI: 56.04370094172866
# RSI sell: False, RSI buy: False
#
# Received price snapshot for JPY= as of 10:46:32
# Short SMA: 148.35699999999997 Long SMA: 148.3485
# SMA sell: False, SMA buy: True
# SlowK: 38.23959956556079 SlowD: 57.14349425214013
# Stoch sell: False, Stoch buy: False
# RSI: 47.862080843542664
# RSI sell: False, RSI buy: False
#
# Received price snapshot for GBP= as of 10:47:32
# Short SMA: 1.24748 Long SMA: 1.247735
# SMA sell: False, SMA buy: False
# SlowK: 31.43939393939567 SlowD: 21.282267115601318
# Stoch sell: False, Stoch buy: False
# RSI: 38.69923390003167
# RSI sell: False, RSI buy: False
#
# Received price snapshot for EUR= as of 10:47:32
# Short SMA: 1.0927499999999999 Long SMA: 1.0928050000000002
# SMA sell: True, SMA buy: False
# SlowK: 52.121212121211975 SlowD: 29.141414141414106
# Stoch sell: False, Stoch buy: False
# RSI: 60.819369991918606
# RSI sell: False, RSI buy: False
#
# Received price snapshot for JPY= as of 10:47:33
# Short SMA: 148.36999999999998 Long SMA: 148.3485
# SMA sell: False, SMA buy: False
# SlowK: 19.21424186617552 SlowD: 38.88062520658682
# Stoch sell: False, Stoch buy: False
# RSI: 47.862080843542664
# RSI sell: False, RSI buy: False
#
# Received price snapshot for GBP= as of 10:48:33
# Short SMA: 1.24735 Long SMA: 1.2476850000000002
# SMA sell: False, SMA buy: False
# SlowK: 38.88888888889057 SlowD: 30.611672278340375
# Stoch sell: False, Stoch buy: False
# RSI: 31.3766391069511
# RSI sell: False, RSI buy: False
#
# Received price snapshot for EUR= as of 10:48:33
# Short SMA: 1.0926699999999998 Long SMA: 1.0928100000000003
# SMA sell: False, SMA buy: False
# SlowK: 67.42424242424231 SlowD: 49.39393939393932
# Stoch sell: False, Stoch buy: False
# RSI: 54.44869746194109
# RSI sell: False, RSI buy: False
#
# Received price snapshot for JPY= as of 10:48:33
# Short SMA: 148.37999999999997 Long SMA: 148.3475
# SMA sell: False, SMA buy: False
# SlowK: 11.78637200736622 SlowD: 23.080071146367516
# Stoch sell: False, Stoch buy: False
# RSI: 44.55014731142135
# RSI sell: False, RSI buy: False
#
# Received price snapshot for GBP= as of 10:49:32
# Short SMA: 1.24722 Long SMA: 1.2476150000000001
# SMA sell: False, SMA buy: False
# SlowK: 35.35353535353627 SlowD: 35.227272727274176
# Stoch sell: False, Stoch buy: False
# RSI: 27.217056642807623
# RSI sell: False, RSI buy: True
#
# Received price snapshot for EUR= as of 10:49:31
# Short SMA: 1.0926099999999999 Long SMA: 1.0928200000000001
# SMA sell: False, SMA buy: False
# SlowK: 68.18181818181796 SlowD: 62.575757575757414
# Stoch sell: False, Stoch buy: False
# RSI: 56.880730376382424
# RSI sell: False, RSI buy: False
#
# Received price snapshot for JPY= as of 10:49:33
# Short SMA: 148.38599999999997 Long SMA: 148.347
# SMA sell: False, SMA buy: False
# SlowK: 11.41804788213583 SlowD: 14.139553918559196
# Stoch sell: False, Stoch buy: False
# RSI: 44.55014731142135
# RSI sell: False, RSI buy: False
#
# Received price snapshot for GBP= as of 10:50:33
# Short SMA: 1.24711 Long SMA: 1.24755
# SMA sell: False, SMA buy: False
# SlowK: 33.838383838383784 SlowD: 36.02693602693688
# Stoch sell: False, Stoch buy: False
# RSI: 38.85615823120504
# RSI sell: False, RSI buy: False
#
# Received price snapshot for EUR= as of 10:50:31
# Short SMA: 1.0925699999999998 Long SMA: 1.0928250000000002
# SMA sell: False, SMA buy: False
# SlowK: 67.42424242424232 SlowD: 67.67676767676753
# Stoch sell: False, Stoch buy: False
# RSI: 56.88073037638244
# RSI sell: False, RSI buy: False
#
# Received price snapshot for JPY= as of 10:50:33
# Short SMA: 148.38399999999996 Long SMA: 148.344
# SMA sell: False, SMA buy: False
# SlowK: 9.944751381214793 SlowD: 11.049723756905621
# Stoch sell: False, Stoch buy: False
# RSI: 35.905590525563966
# RSI sell: False, RSI buy: False
# <OpenState.Closed: 'Closed'>

# %%
pd.DataFrame(asset_dict['GBP='])
# Out:
#         Date      Time  short_sma  long_sma  sma_sell  sma_buy        rsi  \
# 0 2023-11-17  16:29:50    1.24221  1.242510     False    False  39.285530
# 1 2023-11-17  16:30:48    1.24217  1.242460     False    False  35.728327
# 2 2023-11-17  16:31:50    1.24213  1.242400     False    False  35.728327
# 3 2023-11-17  16:32:51    1.24206  1.242315     False    False  32.332931
# 4 2023-11-17  16:33:50    1.24201  1.242255     False    False  41.338423
#
#    rsi_sell  rsi_buy      slowK      slowD  stoch_sell  stoch_buy
# 0     False    False  49.154589  40.992046       False      False
# 1     False    False  61.231884  50.179330       False      False
# 2     False    False  70.531401  60.305958       False      False
# 3     False    False  68.599034  66.787440       False      False
# 4     False    False  69.082126  69.404187       False      False

# %% [markdown]
# ### Function with stream recording

# %% [markdown]
# This function doesn not combine historical and snapshot data and isntead records the stream in provided interval and duration and builds the indicator on the records. In this function we first run the recorder for a required duration to calculate the provided indicators (e.g for the length of long moving average) and then record with minute interval with 1 minute duration.

# %%
def run_ta_stream_recorder(assets, asset_dict, stream, tech_indicators, price_metric, bar, duration, first_run):
    stream.recorder.record(frequency=bar, duration = duration)
    assets_prices = stream.recorder.get_history()
    if not first_run:
        for asset in assets:
 
            prices_asset = assets_prices[asset][price_metric]
            print(f'Build bar for {asset} with {prices_asset.last_valid_index()} timstamp')

            short_sma, long_sma, sma_sell, sma_buy = get_sma(prices_asset['close'],tech_indicators['s_ma'], tech_indicators['l_ma'])
            print(f' Short SMA: {short_sma} Long SMA: {long_sma} \n sma_sell: {sma_sell}, sma_buy: {sma_buy}')

            slowk, slowd, stoch_sell, stoch_buy  = get_stoch(prices_asset['close'], prices_asset['high'], prices_asset['low'])
            print(f' SlowK: {slowk} SlowD: {slowd} \n stoch_sell: {stoch_sell}, stoch_buy: {stoch_buy}')

            rsi, rsi_sell,rsi_buy  = get_rsi(prices_asset['close'], tech_indicators['rsi_period'])   
            print(f' RSI: {rsi} \n rsi_sell: {rsi_sell}, rsi_buy: {rsi_buy}\n')
            asset_dict[asset].append({'Timestamp':prices_asset.last_valid_index(),'short_sma':short_sma, 'long_sma':long_sma, 'sma_sell':sma_sell, 'sma_buy':sma_buy, 
                                  'rsi':rsi, 'rsi_sell':rsi_sell, 'rsi_buy':rsi_buy,  
                                  'slowK':slowk, 'slowD':slowd, 'stoch_sell':stoch_buy, 'stoch_buy':stoch_buy})

# %% [markdown]
# Now, let's initialize the parameters for this function.

# %%
asset_dict = {'GBP=':[], 'EUR=':[], 'JPY=':[]}
assets = list(asset_dict.keys())
first_run = True
bar = '1min'
price_metric = 'BID'
tech_indicators = {'s_ma':5, 'l_ma':10, 'rsi_period': 14}
timeout = time.time() + 1080

# %% [markdown]
# And finally, we open and record the stream by building the minute bars along with the ta triggers.

# %%
stream = rd.open_pricing_stream(universe= assets, fields=['BID', 'ASK', 'MID_PRICE', 'CF_LAST'])

while time.time() < timeout:
    duration = bar
    if first_run:
        multiplier = int(re.findall(r'\d+', bar)[0])
        duration = f"{multiplier*max(tech_indicators['l_ma'], tech_indicators['rsi_period'])}min"
        first_run = False
    assets_prices = run_ta_stream_recorder(assets, asset_dict, stream, tech_indicators, price_metric, bar, duration, first_run)
stream.recorder.stop()
stream.close()
# Out:
# 1min 20min
# Build bar for GBP= with 2023-11-17 12:57:23.350985 timstamp
#  Short SMA: 1.2432100000000001 Long SMA: 1.2433299999999998
#  sma_sell: False, sma_buy: False
#  SlowK: 30.7142857142872 SlowD: 26.843033509704373
#  stoch_sell: False, stoch_buy: False
#  RSI: 54.763826360881026
#  rsi_sell: False, rsi_buy: False
#
# Build bar for EUR= with 2023-11-17 12:57:23.350985 timstamp
#  Short SMA: 1.08644 Long SMA: 1.0864300000000005
#  sma_sell: False, sma_buy: False
#  SlowK: 22.22222222222221 SlowD: 17.407407407407405
#  stoch_sell: False, stoch_buy: True
#  RSI: 50.05357710802165
#  rsi_sell: False, rsi_buy: False
#
# Build bar for JPY= with 2023-11-17 12:57:23.350985 timstamp
#  Short SMA: 149.25500000000002 Long SMA: 149.28750000000002
#  sma_sell: False, sma_buy: False
#  SlowK: 44.781144781149855 SlowD: 58.383838383843425
#  stoch_sell: False, stoch_buy: False
#  RSI: 44.22114177715731
#  rsi_sell: False, rsi_buy: False
#
# 1min 1min
# Build bar for GBP= with 2023-11-17 12:58:23.446779 timstamp
#  Short SMA: 1.2431500000000002 Long SMA: 1.2433349999999999
#  sma_sell: False, sma_buy: False
#  SlowK: 44.04761904761665 SlowD: 32.14285714285754
#  stoch_sell: False, stoch_buy: False
#  RSI: 50.29772927983475
#  rsi_sell: False, rsi_buy: False
#
# Build bar for EUR= with 2023-11-17 12:58:23.446779 timstamp
#  Short SMA: 1.0863900000000002 Long SMA: 1.0864300000000005
#  sma_sell: True, sma_buy: False
#  SlowK: 33.33333333333332 SlowD: 24.074074074074073
#  stoch_sell: False, stoch_buy: False
#  RSI: 46.91971225335983
#  rsi_sell: False, rsi_buy: False
#
# Build bar for JPY= with 2023-11-17 12:58:23.446779 timstamp
#  Short SMA: 149.25900000000001 Long SMA: 149.2855
#  sma_sell: False, sma_buy: False
#  SlowK: 34.19913419913673 SlowD: 46.20330286997418
#  stoch_sell: False, stoch_buy: False
#  RSI: 49.00872191299252
#  rsi_sell: False, rsi_buy: False
#
# 1min 1min
# Build bar for GBP= with 2023-11-17 12:59:23.511672 timstamp
#  Short SMA: 1.2431 Long SMA: 1.243325
#  sma_sell: False, sma_buy: False
#  SlowK: 46.825396825394 SlowD: 40.529100529099274
#  stoch_sell: False, stoch_buy: False
#  RSI: 46.23695986988396
#  rsi_sell: False, rsi_buy: False
#
# Build bar for EUR= with 2023-11-17 12:59:23.511672 timstamp
#  Short SMA: 1.0863400000000003 Long SMA: 1.0864200000000002
#  sma_sell: False, sma_buy: False
#  SlowK: 16.666666666666654 SlowD: 24.074074074074073
#  stoch_sell: False, stoch_buy: False
#  RSI: 41.34431718317737
#  rsi_sell: False, rsi_buy: False
#
# Build bar for JPY= with 2023-11-17 12:59:23.511672 timstamp
#  Short SMA: 149.26500000000001 Long SMA: 149.28400000000002
#  sma_sell: False, sma_buy: False
#  SlowK: 62.770562770563366 SlowD: 47.25028058361664
#  stoch_sell: False, stoch_buy: False
#  RSI: 54.60360737031104
#  rsi_sell: False, rsi_buy: False
#
# 1min 1min
# Build bar for GBP= with 2023-11-17 13:00:23.581040 timstamp
#  Short SMA: 1.2429999999999999 Long SMA: 1.2432949999999998
#  sma_sell: False, sma_buy: False
#  SlowK: 36.111111111101444 SlowD: 42.328042328037355
#  stoch_sell: False, stoch_buy: False
#  RSI: 44.31066441617003
#  rsi_sell: False, rsi_buy: False
#
# Build bar for EUR= with 2023-11-17 13:00:23.581040 timstamp
#  Short SMA: 1.0862900000000002 Long SMA: 1.086405
#  sma_sell: False, sma_buy: False
#  SlowK: 16.666666666666654 SlowD: 22.222222222222218
#  stoch_sell: False, stoch_buy: False
#  RSI: 44.87167709695065
#  rsi_sell: False, rsi_buy: False
#
# Build bar for JPY= with 2023-11-17 13:00:23.581040 timstamp
#  Short SMA: 149.275 Long SMA: 149.28300000000002
#  sma_sell: False, sma_buy: False
#  SlowK: 72.61904761904812 SlowD: 56.52958152958272
#  stoch_sell: False, stoch_buy: False
#  RSI: 54.60360737031104
#  rsi_sell: False, rsi_buy: False
#
# 1min 1min
# Build bar for GBP= with 2023-11-17 13:01:23.647899 timstamp
#  Short SMA: 1.2429199999999998 Long SMA: 1.2432649999999996
#  sma_sell: False, sma_buy: False
#  SlowK: 31.944444444435934 SlowD: 38.293650793643785
#  stoch_sell: False, stoch_buy: False
#  RSI: 46.70194044213278
#  rsi_sell: False, rsi_buy: False
#
# Build bar for EUR= with 2023-11-17 13:01:23.647899 timstamp
#  Short SMA: 1.08624 Long SMA: 1.0863900000000002
#  sma_sell: False, sma_buy: False
#  SlowK: 18.888888888888875 SlowD: 17.407407407407405
#  stoch_sell: False, stoch_buy: True
#  RSI: 48.22477590277231
#  rsi_sell: False, rsi_buy: False
#
# Build bar for JPY= with 2023-11-17 13:01:23.647899 timstamp
#  Short SMA: 149.29500000000002 Long SMA: 149.286
#  sma_sell: False, sma_buy: True
#  SlowK: 84.523809523811 SlowD: 73.30447330447414
#  stoch_sell: False, stoch_buy: False
#  RSI: 60.8336099506096
#  rsi_sell: False, rsi_buy: False
#
# 1min 1min
# Build bar for GBP= with 2023-11-17 13:02:23.756639 timstamp
#  Short SMA: 1.2428499999999998 Long SMA: 1.2432149999999997
#  sma_sell: False, sma_buy: False
#  SlowK: 31.944444444434566 SlowD: 33.33333333332397
#  stoch_sell: False, stoch_buy: False
#  RSI: 44.63777321656943
#  rsi_sell: False, rsi_buy: False
#
# Build bar for EUR= with 2023-11-17 13:02:23.756639 timstamp
#  Short SMA: 1.08622 Long SMA: 1.0863800000000001
#  sma_sell: False, sma_buy: False
#  SlowK: 45.55555555555554 SlowD: 27.037037037037035
#  stoch_sell: False, stoch_buy: False
#  RSI: 54.22191193011856
#  rsi_sell: False, rsi_buy: False
#
# Build bar for JPY= with 2023-11-17 13:02:23.756639 timstamp
#  Short SMA: 149.311 Long SMA: 149.291
#  sma_sell: False, sma_buy: False
#  SlowK: 85.9523809523872 SlowD: 81.03174603174875
#  stoch_sell: False, stoch_buy: False
#  RSI: 60.83360995060961
#  rsi_sell: False, rsi_buy: False
#
# 1min 1min
# Build bar for GBP= with 2023-11-17 13:03:23.856850 timstamp
#  Short SMA: 1.2428099999999997 Long SMA: 1.2431699999999997
#  sma_sell: False, sma_buy: False
#  SlowK: 42.65873015871655 SlowD: 35.51587301586235
#  stoch_sell: False, stoch_buy: False
#  RSI: 49.449997020436314
#  rsi_sell: False, rsi_buy: False
#
# Build bar for EUR= with 2023-11-17 13:03:23.856850 timstamp
#  Short SMA: 1.08621 Long SMA: 1.086375
#  sma_sell: False, sma_buy: False
#  SlowK: 67.77777777777777 SlowD: 44.074074074074076
#  stoch_sell: False, stoch_buy: False
#  RSI: 56.90947337294605
#  rsi_sell: False, rsi_buy: False
#
# Build bar for JPY= with 2023-11-17 13:03:23.856850 timstamp
#  Short SMA: 149.32600000000002 Long SMA: 149.29500000000002
#  sma_sell: False, sma_buy: False
#  SlowK: 77.61904761905238 SlowD: 82.69841269841685
#  stoch_sell: True, stoch_buy: False
#  RSI: 57.192487952910874
#  rsi_sell: False, rsi_buy: False
#
# 1min 1min
# Build bar for GBP= with 2023-11-17 13:04:23.934189 timstamp
#  Short SMA: 1.2427999999999997 Long SMA: 1.2431299999999994
#  sma_sell: False, sma_buy: False
#  SlowK: 53.968253968236276 SlowD: 42.857142857129126
#  stoch_sell: False, stoch_buy: False
#  RSI: 51.7101747359487
#  rsi_sell: False, rsi_buy: False
#
# Build bar for EUR= with 2023-11-17 13:04:23.934189 timstamp
#  Short SMA: 1.08621 Long SMA: 1.0863650000000002
#  sma_sell: False, sma_buy: False
#  SlowK: 74.44444444444444 SlowD: 62.5925925925926
#  stoch_sell: False, stoch_buy: False
#  RSI: 53.52535906412734
#  rsi_sell: False, rsi_buy: False
#
# Build bar for JPY= with 2023-11-17 13:04:23.934189 timstamp
#  Short SMA: 149.33900000000003 Long SMA: 149.301
#  sma_sell: False, sma_buy: False
#  SlowK: 75.83333333333913 SlowD: 79.80158730159287
#  stoch_sell: False, stoch_buy: False
#  RSI: 60.966514235849715
#  rsi_sell: False, rsi_buy: False
#
# 1min 1min
# Build bar for GBP= with 2023-11-17 13:05:24.026766 timstamp
#  Short SMA: 1.2427999999999997 Long SMA: 1.2430799999999995
#  sma_sell: False, sma_buy: False
#  SlowK: 55.35714285712581 SlowD: 50.661375661359536
#  stoch_sell: False, stoch_buy: False
#  RSI: 49.33465740540351
#  rsi_sell: False, rsi_buy: False
#
# Build bar for EUR= with 2023-11-17 13:05:24.026766 timstamp
#  Short SMA: 1.08621 Long SMA: 1.0863500000000001
#  sma_sell: False, sma_buy: False
#  SlowK: 60.27777777777777 SlowD: 67.50000000000001
#  stoch_sell: False, stoch_buy: False
#  RSI: 53.52535906412734
#  rsi_sell: False, rsi_buy: False
#
# Build bar for JPY= with 2023-11-17 13:05:24.026766 timstamp
#  Short SMA: 149.35300000000004 Long SMA: 149.3075
#  sma_sell: False, sma_buy: False
#  SlowK: 79.16666666666963 SlowD: 77.53968253968702
#  stoch_sell: False, stoch_buy: False
#  RSI: 62.16395514995272
#  rsi_sell: False, rsi_buy: False
#
# 1min 1min
# Build bar for GBP= with 2023-11-17 13:06:24.118362 timstamp
#  Short SMA: 1.2428199999999996 Long SMA: 1.2430499999999995
#  sma_sell: False, sma_buy: False
#  SlowK: 56.30952380951576 SlowD: 55.21164021162594
#  stoch_sell: False, stoch_buy: False
#  RSI: 55.882510496896465
#  rsi_sell: False, rsi_buy: False
#
# Build bar for EUR= with 2023-11-17 13:06:24.118362 timstamp
#  Short SMA: 1.0862200000000002 Long SMA: 1.0863550000000002
#  sma_sell: False, sma_buy: False
#  SlowK: 54.72222222222221 SlowD: 63.14814814814815
#  stoch_sell: False, stoch_buy: False
#  RSI: 61.49240732943478
#  rsi_sell: False, rsi_buy: False
#
# Build bar for JPY= with 2023-11-17 13:06:24.118362 timstamp
#  Short SMA: 149.36500000000004 Long SMA: 149.3105
#  sma_sell: False, sma_buy: False
#  SlowK: 76.38888888888987 SlowD: 77.12962962963286
#  stoch_sell: False, stoch_buy: False
#  RSI: 50.488104172371116
#  rsi_sell: False, rsi_buy: False
#
# 1min 1min
# Build bar for GBP= with 2023-11-17 13:07:24.257468 timstamp
#  Short SMA: 1.2428499999999996 Long SMA: 1.2430299999999996
#  sma_sell: False, sma_buy: False
#  SlowK: 59.16666666666765 SlowD: 56.94444444443641
#  stoch_sell: False, stoch_buy: False
#  RSI: 61.27254542942694
#  rsi_sell: False, rsi_buy: False
#
# Build bar for EUR= with 2023-11-17 13:07:24.257468 timstamp
#  Short SMA: 1.0862700000000003 Long SMA: 1.0863550000000002
#  sma_sell: False, sma_buy: False
#  SlowK: 60.64814814814813 SlowD: 58.54938271604939
#  stoch_sell: False, stoch_buy: False
#  RSI: 63.72472282183047
#  rsi_sell: False, rsi_buy: False
#
# Build bar for JPY= with 2023-11-17 13:07:24.257468 timstamp
#  Short SMA: 149.37100000000004 Long SMA: 149.31300000000002
#  sma_sell: False, sma_buy: False
#  SlowK: 58.33333333333135 SlowD: 71.29629629629694
#  stoch_sell: False, stoch_buy: False
#  RSI: 49.07017621435464
#  rsi_sell: False, rsi_buy: False
# <OpenState.Closed: 'Closed'>

# %%
pd.DataFrame(asset_dict['GBP='])
# Out:
#                     Timestamp  short_sma  long_sma  sma_sell  sma_buy  \
# 0  2023-11-17 12:57:23.350985    1.24321  1.243330     False    False
# 1  2023-11-17 12:58:23.446779    1.24315  1.243335     False    False
# 2  2023-11-17 12:59:23.511672    1.24310  1.243325     False    False
# 3  2023-11-17 13:00:23.581040    1.24300  1.243295     False    False
# 4  2023-11-17 13:01:23.647899    1.24292  1.243265     False    False
# 5  2023-11-17 13:02:23.756639    1.24285  1.243215     False    False
# 6  2023-11-17 13:03:23.856850    1.24281  1.243170     False    False
# 7  2023-11-17 13:04:23.934189    1.24280  1.243130     False    False
# 8  2023-11-17 13:05:24.026766    1.24280  1.243080     False    False
# 9  2023-11-17 13:06:24.118362    1.24282  1.243050     False    False
# 10 2023-11-17 13:07:24.257468    1.24285  1.243030     False    False
#
#           rsi  rsi_sell  rsi_buy      slowK      slowD  stoch_sell  stoch_buy
# 0   54.763826     False    False  30.714286  26.843034       False      False
# 1   50.297729     False    False  44.047619  32.142857       False      False
# 2   46.236960     False    False  46.825397  40.529101       False      False
# 3   44.310664     False    False  36.111111  42.328042       False      False
# 4   46.701940     False    False  31.944444  38.293651       False      False
# 5   44.637773     False    False  31.944444  33.333333       False      False
# 6   49.449997     False    False  42.658730  35.515873       False      False
# 7   51.710175     False    False  53.968254  42.857143       False      False
# 8   49.334657     False    False  55.357143  50.661376       False      False
# 9   55.882510     False    False  56.309524  55.211640       False      False
# 10  61.272545     False    False  59.166667  56.944444       False      False

# %% [markdown]
# ### Further Resources for Refinitiv Data Libraries API on Developer Community Portal
#
# * [Overview](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python)
# * [Quick Start ](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/quick-start)
# * [Documentation](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/documentation)
# * [Tutorials](https://developers.refinitiv.com/en/api-catalog/refinitiv-data-platform/refinitiv-data-library-for-python/tutorials)
# * [Q&A Forums](https://community.developers.refinitiv.com/spaces/321/index.html)
